# %% [markdown]
# #### Tool

# %%
import shutil
from imutils import paths
import random
import os

# Lấy các đường dẫn đến ảnh
image_paths = list(paths.list_images('Dataset'))

# Đổi vị trí ngẫu nhiên các đường dẫn ảnh
random.shuffle(image_paths)

# Chỉ lấy 5000 dòng đầu tiên (5000 ảnh)
selected_image_paths = image_paths[:2000]

# Thư mục đích để sao chép
destination_folder = 'dataset_2000'

# Tạo thư mục đích nếu nó không tồn tại
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Sao chép các tệp ảnh vào thư mục đích
for image_path in selected_image_paths:
    filename = os.path.basename(image_path)
    destination_path = os.path.join(destination_folder, filename)
    shutil.copyfile(image_path, destination_path)

print("Sao chép hoàn tất.")
# Out:
# Sao chép hoàn tất.

# %% [markdown]
# #### UnZip and Create Folder

# %% [markdown]
# - File .zip sẽ là file chứa toàn bộ các ảnh tên của ảnh là nhãn ví dụ cat.1.jpg ; cat.2.jpg ; dot.1.jpg,...
# - Tạo một folder Dataset ngang hàng với file này , cho vào đó file .zip chứa toàn bộ các ảnh
# - Chạy file nó sẽ giải nén và tạo ra các folder train , val , test
# - LƯU Ý : Cần chỉnh lại : labels = ['mild', 'moderate', 'non', 'verymild'] đúng với các nhãn của tập dữ liệu

# %%
import os
import shutil
import random
import zipfile

# Giải nén tệp data_500.zip vào thư mục data_500
data_zip_path = 'Dataset/dataset_2000.zip'
data_dir = 'Dataset/dataset_2000'
root_dir = 'Dataset/'

# with zipfile.ZipFile(data_zip_path, 'r') as zip_ref:
#     zip_ref.extractall(root_dir)

# Đường dẫn tới thư mục con 'train', 'val' và 'test'
train_dir = os.path.join(root_dir, 'train')
val_dir = os.path.join(root_dir, 'val')
test_dir = os.path.join(root_dir, 'test')

# Tạo các thư mục con 'train', 'val' và 'test'
os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# Danh sách các nhãn
labels = ['cat', 'dog'] 

# Tỷ lệ train:val:test
train_ratio = 0.7
val_ratio = 0.2
test_ratio = 0.1

# Lặp qua các nhãn
for label in labels:
    # Tạo các thư mục con 'dog' và 'cat' trong 'train', 'val' và 'test'
    os.makedirs(os.path.join(train_dir, label), exist_ok=True)
    os.makedirs(os.path.join(val_dir, label), exist_ok=True)
    os.makedirs(os.path.join(test_dir, label), exist_ok=True)

    # Đường dẫn tới các tệp thuộc nhãn hiện tại
    label_files = [file for file in os.listdir(data_dir) if file.startswith(label)]
    print(data_dir)
    print(label_files)
    
    # Sắp xếp ngẫu nhiên các tệp
    random.shuffle(label_files)

    # Số lượng tệp trong từng thư mục con
    num_files = len(label_files)
    num_train = int(num_files * train_ratio)
    num_val = int(num_files * val_ratio)
    num_test = num_files - num_train - num_val

    # Chia các tệp vào các thư mục con tương ứng
    train_files = label_files[:num_train]
    val_files = label_files[num_train:num_train + num_val]
    test_files = label_files[num_train + num_val:]

    for file in train_files:
        src = os.path.join(data_dir, file)
        dst = os.path.join(train_dir, label, file)
        shutil.copy2(src, dst)

    for file in val_files:
        src = os.path.join(data_dir, file)
        dst = os.path.join(val_dir, label, file)
        shutil.copy2(src, dst)

    for file in test_files:
        src = os.path.join(data_dir, file)
        dst = os.path.join(test_dir, label, file)
        shutil.copy2(src, dst)
# Out:
# Dataset/dataset_2000
# ['cat.1.jpg', 'cat.10012.jpg', 'cat.10013.jpg', 'cat.10016.jpg', 'cat.10030.jpg', 'cat.10059.jpg', 'cat.10078.jpg', 'cat.1008.jpg', 'cat.10098.jpg', 'cat.1010.jpg', 'cat.10107.jpg', 'cat.10110.jpg', 'cat.10120.jpg', 'cat.1013.jpg', 'cat.10133.jpg', 'cat.10134.jpg', 'cat.10135.jpg', 'cat.10137.jpg', 'cat.1015.jpg', 'cat.10155.jpg', 'cat.10163.jpg', 'cat.10226.jpg', 'cat.10231.jpg', 'cat.10238.jpg', 'cat.10249.jpg', 'cat.10255.jpg', 'cat.10262.jpg', 'cat.10267.jpg', 'cat.10271.jpg', 'cat.10284.jpg', 'cat.10306.jpg', 'cat.10314.jpg', 'cat.10319.jpg', 'cat.10348.jpg', 'cat.10395.jpg', 'cat.10397.jpg', 'cat.104.jpg', 'cat.10415.jpg', 'cat.10430.jpg', 'cat.10431.jpg', 'cat.10484.jpg', 'cat.10490.jpg', 'cat.10497.jpg', 'cat.10513.jpg', 'cat.10527.jpg', 'cat.10531.jpg', 'cat.10539.jpg', 'cat.10546.jpg', 'cat.10557.jpg', 'cat.10574.jpg', 'cat.10577.jpg', 'cat.10579.jpg', 'cat.10588.jpg', 'cat.10609.jpg', 'cat.10613.jpg', 'cat.10617.jpg', 'cat.10633.jpg', 'cat.10655.jpg', 'cat.10669.jpg', 'cat.10675.jpg', 'cat.10679.jpg', 'cat.10685.jpg', 'cat.10706.jpg', 'cat.10740.jpg', 'cat.10746.jpg', 'cat.10751.jpg', 'cat.10775.jpg', 'cat.10779.jpg', 'cat.1078.jpg', 'cat.10787.jpg', 'cat.10812.jpg', 'cat.10818.jpg', 'cat.10822.jpg', 'cat.10827.jpg', 'cat.10835.jpg', 'cat.10840.jpg', 'cat.10846.jpg', 'cat.10851.jpg', 'cat.1087.jpg', 'cat.10876.jpg', 'cat.10877.jpg', 'cat.10909.jpg', 'cat.10920.jpg', 'cat.10921.jpg', 'cat.10923.jpg', 'cat.10938.jpg', 'cat.10954.jpg', 'cat.10968.jpg', 'cat.10986.jpg', 'cat.10990.jpg', 'cat.11.jpg', 'cat.11000.jpg', 'cat.11001.jpg', 'cat.1104.jpg', 'cat.11046.jpg', 'cat.11051.jpg', 'cat.11059.jpg', 'cat.1107.jpg', 'cat.11071.jpg', 'cat.11101.jpg', 'cat.11106.jpg', 'cat.11120.jpg', 'cat.11121.jpg', 'cat.11139.jpg', 'cat.11150.jpg', 'cat.11157.jpg', 'cat.11162.jpg', 'cat.11168.jpg', 'cat.11170.jpg', 'cat.11175.jpg', 'cat.11182.jpg', 'cat.11197.jpg', 'cat.1121.jpg', 'cat.11231.jpg', 'cat.11237.jpg', 'cat.11238.jpg', 'cat.11241.jpg', 'cat.11247.jpg', 'cat.1125.jpg', 'cat.11255.jpg', 'cat.11259.jpg', 'cat.1126.jpg', 'cat.11281.jpg', 'cat.11294.jpg', 'cat.11301.jpg', 'cat.11313.jpg', 'cat.11330.jpg', 'cat.11334.jpg', 'cat.11357.jpg', 'cat.11359.jpg', 'cat.11360.jpg', 'cat.11372.jpg', 'cat.11385.jpg', 'cat.11392.jpg', 'cat.11393.jpg', 'cat.1142.jpg', 'cat.11448.jpg', 'cat.11477.jpg', 'cat.11503.jpg', 'cat.1152.jpg', 'cat.11521.jpg', 'cat.11529.jpg', 'cat.11534.jpg', 'cat.11537.jpg', 'cat.11542.jpg', 'cat.11546.jpg', 'cat.11550.jpg', 'cat.11556.jpg', 'cat.11561.jpg', 'cat.11563.jpg', 'cat.1157.jpg', 'cat.11571.jpg', 'cat.11578.jpg', 'cat.116.jpg', 'cat.11620.jpg', 'cat.11643.jpg', 'cat.11648.jpg', 'cat.11650.jpg', 'cat.11666.jpg', 'cat.11670.jpg', 'cat.11678.jpg', 'cat.11685.jpg', 'cat.11686.jpg', 'cat.11688.jpg', 'cat.11690.jpg', 'cat.11700.jpg', 'cat.11745.jpg', 'cat.1175.jpg', 'cat.11780.jpg', 'cat.11801.jpg', 'cat.1183.jpg', 'cat.11861.jpg', 'cat.11866.jpg', 'cat.11870.jpg', 'cat.11874.jpg', 'cat.11904.jpg', 'cat.11919.jpg', 'cat.11944.jpg', 'cat.11960.jpg', 'cat.11965.jpg', 'cat.11967.jpg', 'cat.11977.jpg', 'cat.1199.jpg', 'cat.11998.jpg', 'cat.12005.jpg', 'cat.12014.jpg', 'cat.12026.jpg', 'cat.12030.jpg', 'cat.1204.jpg', 'cat.12045.jpg', 'cat.12049.jpg', 'cat.12056.jpg', 'cat.12083.jpg', 'cat.12090.jpg', 'cat.12106.jpg', 'cat.12115.jpg', 'cat.12132.jpg', 'cat.12151.jpg', 'cat.12154.jpg', 'cat.12166.jpg', 'cat.12169.jpg', 'cat.12182.jpg', 'cat.12183.jpg', 'cat.12188.jpg', 'cat.12198.jpg', 'cat.12205.jpg', 'cat.12231.jpg', 'cat.12235.jpg', 'cat.12264.jpg', 'cat.12268.jpg', 'cat.12273.jpg', 'cat.12283.jpg', 'cat.12292.jpg', 'cat.12304.jpg', 'cat.12311.jpg', 'cat.12320.jpg', 'cat.12322.jpg', 'cat.12332.jpg', 'cat.12363.jpg', 'cat.12373.jpg', 'cat.12380.jpg', 'cat.1239.jpg', 'cat.12390.jpg', 'cat.12391.jpg', 'cat.12405.jpg', 'cat.12409.jpg', 'cat.12440.jpg', 'cat.12443.jpg', 'cat.12455.jpg', 'cat.12467.jpg', 'cat.12469.jpg', 'cat.1262.jpg', 'cat.1307.jpg', 'cat.1320.jpg', 'cat.1329.jpg', 'cat.1332.jpg', 'cat.134.jpg', 'cat.13 ...
# Dataset/dataset_2000
# ['dog.0.jpg', 'dog.10023.jpg', 'dog.10045.jpg', 'dog.1005.jpg', 'dog.10057.jpg', 'dog.10060.jpg', 'dog.10073.jpg', 'dog.10074.jpg', 'dog.10137.jpg', 'dog.10207.jpg', 'dog.10233.jpg', 'dog.10241.jpg', 'dog.10244.jpg', 'dog.10308.jpg', 'dog.10315.jpg', 'dog.10318.jpg', 'dog.10345.jpg', 'dog.10349.jpg', 'dog.10358.jpg', 'dog.10360.jpg', 'dog.10366.jpg', 'dog.10374.jpg', 'dog.10393.jpg', 'dog.10437.jpg', 'dog.10451.jpg', 'dog.10466.jpg', 'dog.10495.jpg', 'dog.105.jpg', 'dog.10500.jpg', 'dog.10501.jpg', 'dog.10503.jpg', 'dog.1051.jpg', 'dog.10519.jpg', 'dog.10537.jpg', 'dog.10543.jpg', 'dog.10549.jpg', 'dog.10550.jpg', 'dog.10552.jpg', 'dog.10557.jpg', 'dog.10562.jpg', 'dog.10564.jpg', 'dog.10565.jpg', 'dog.1057.jpg', 'dog.10577.jpg', 'dog.10578.jpg', 'dog.10598.jpg', 'dog.10613.jpg', 'dog.10631.jpg', 'dog.10635.jpg', 'dog.10639.jpg', 'dog.10648.jpg', 'dog.10665.jpg', 'dog.1069.jpg', 'dog.10717.jpg', 'dog.10725.jpg', 'dog.10734.jpg', 'dog.10743.jpg', 'dog.10752.jpg', 'dog.10753.jpg', 'dog.10757.jpg', 'dog.10767.jpg', 'dog.10777.jpg', 'dog.10787.jpg', 'dog.1079.jpg', 'dog.10792.jpg', 'dog.10794.jpg', 'dog.10819.jpg', 'dog.10832.jpg', 'dog.1085.jpg', 'dog.1086.jpg', 'dog.10876.jpg', 'dog.10877.jpg', 'dog.10886.jpg', 'dog.10910.jpg', 'dog.10919.jpg', 'dog.1092.jpg', 'dog.1093.jpg', 'dog.10935.jpg', 'dog.10967.jpg', 'dog.10975.jpg', 'dog.10994.jpg', 'dog.10996.jpg', 'dog.11020.jpg', 'dog.11031.jpg', 'dog.11042.jpg', 'dog.11044.jpg', 'dog.11047.jpg', 'dog.11049.jpg', 'dog.11050.jpg', 'dog.11055.jpg', 'dog.11060.jpg', 'dog.11066.jpg', 'dog.11069.jpg', 'dog.11098.jpg', 'dog.11125.jpg', 'dog.11134.jpg', 'dog.11138.jpg', 'dog.1114.jpg', 'dog.11143.jpg', 'dog.11185.jpg', 'dog.1122.jpg', 'dog.11220.jpg', 'dog.11228.jpg', 'dog.11263.jpg', 'dog.11267.jpg', 'dog.11268.jpg', 'dog.11284.jpg', 'dog.11295.jpg', 'dog.1130.jpg', 'dog.11304.jpg', 'dog.11324.jpg', 'dog.11340.jpg', 'dog.11346.jpg', 'dog.11358.jpg', 'dog.11379.jpg', 'dog.11387.jpg', 'dog.11392.jpg', 'dog.11403.jpg', 'dog.11409.jpg', 'dog.11436.jpg', 'dog.11443.jpg', 'dog.11462.jpg', 'dog.11479.jpg', 'dog.11481.jpg', 'dog.11494.jpg', 'dog.11502.jpg', 'dog.11505.jpg', 'dog.11518.jpg', 'dog.11530.jpg', 'dog.11537.jpg', 'dog.11541.jpg', 'dog.11559.jpg', 'dog.1156.jpg', 'dog.11561.jpg', 'dog.11566.jpg', 'dog.11568.jpg', 'dog.11584.jpg', 'dog.11601.jpg', 'dog.11602.jpg', 'dog.11620.jpg', 'dog.11628.jpg', 'dog.11633.jpg', 'dog.11667.jpg', 'dog.11670.jpg', 'dog.11677.jpg', 'dog.11687.jpg', 'dog.1169.jpg', 'dog.11705.jpg', 'dog.11711.jpg', 'dog.11721.jpg', 'dog.11783.jpg', 'dog.11791.jpg', 'dog.11801.jpg', 'dog.11826.jpg', 'dog.11866.jpg', 'dog.11871.jpg', 'dog.11892.jpg', 'dog.1191.jpg', 'dog.11938.jpg', 'dog.11973.jpg', 'dog.11994.jpg', 'dog.12001.jpg', 'dog.12007.jpg', 'dog.12009.jpg', 'dog.12012.jpg', 'dog.12032.jpg', 'dog.12033.jpg', 'dog.12035.jpg', 'dog.12045.jpg', 'dog.12052.jpg', 'dog.12063.jpg', 'dog.12075.jpg', 'dog.12077.jpg', 'dog.12088.jpg', 'dog.12089.jpg', 'dog.12111.jpg', 'dog.12117.jpg', 'dog.12148.jpg', 'dog.12155.jpg', 'dog.12158.jpg', 'dog.12164.jpg', 'dog.12183.jpg', 'dog.12187.jpg', 'dog.12202.jpg', 'dog.12230.jpg', 'dog.12246.jpg', 'dog.12268.jpg', 'dog.12274.jpg', 'dog.12279.jpg', 'dog.1228.jpg', 'dog.12285.jpg', 'dog.12288.jpg', 'dog.12315.jpg', 'dog.12324.jpg', 'dog.12347.jpg', 'dog.1235.jpg', 'dog.12395.jpg', 'dog.12397.jpg', 'dog.12429.jpg', 'dog.12430.jpg', 'dog.12439.jpg', 'dog.12481.jpg', 'dog.1258.jpg', 'dog.1275.jpg', 'dog.13.jpg', 'dog.130.jpg', 'dog.1307.jpg', 'dog.1320.jpg', 'dog.1323.jpg', 'dog.1363.jpg', 'dog.1367.jpg', 'dog.1374.jpg', 'dog.1375.jpg', 'dog.1382.jpg', 'dog.1392.jpg', 'dog.1401.jpg', 'dog.1403.jpg', 'dog.1419.jpg', 'dog.1448.jpg', 'dog.1454.jpg', 'dog.1469.jpg', 'dog.1476.jpg', 'dog.1493.jpg', 'dog.1494.jpg', 'dog.1497.jpg', 'dog.15.jpg', 'dog.1502.jpg', 'dog.1507.jpg', 'dog.1512.jpg', 'dog.1524.jpg', 'dog.1536.jpg', 'dog.1543.jpg', 'dog.1550.jpg', 'dog.1555.jpg', 'dog.1577.jpg', 'dog.1580.jpg', 'dog.1589.jpg', 'dog.1591.jpg', 'dog.1613.jpg', ' ...
