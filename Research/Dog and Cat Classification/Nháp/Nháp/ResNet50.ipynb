# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, concatenate, BatchNormalization, Dropout, Activation, MaxPooling2D, GlobalAveragePooling2D, Dense, Add
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from imutils import paths
import pandas as pd
import random
from sklearn.preprocessing import LabelEncoder
from keras.preprocessing.image import img_to_array
from keras.applications import imagenet_utils
from keras.preprocessing.image import load_img
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report , confusion_matrix
import os
import tensorflow as tf
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Tiền xử lí dữ liệu

# %%
# Lấy các đường dẫn đến ảnh.
# image_path = list(paths.list_images('data/dogs-vs-cats/train/train'))
image_path = list(paths.list_images('data_5000/dogs-vs-cats'))

# Đổi vị trí ngẫu nhiên các đường dẫn ảnh
random.shuffle(image_path)

# Chỉ lấy 5000 dòng đầu tiên (5000 ảnh)
# image_path = image_path[:5000]
# print(image_path)

# %%
labels = [p.split(os.path.sep)[-1] for p in image_path]
labels = [label.split('.')[-3] for label in labels]
print(labels)
# Chuyển tên các loài hoa thành số
le = LabelEncoder()
labels = le.fit_transform(labels)
print(labels)
# Out:
# ['dog', 'dog', 'dog', 'cat', 'cat', 'cat', 'dog', 'cat', 'dog', 'cat', 'dog', 'cat', 'dog', 'cat', 'dog', 'cat', 'dog', 'dog', 'dog', 'cat', 'dog', 'cat', 'dog', 'dog', 'cat', 'dog', 'dog', 'cat', 'dog', 'cat', 'cat', 'cat', 'cat', 'dog', 'dog', 'dog', 'dog', 'cat', 'cat', 'cat', 'dog', 'cat', 'cat', 'dog', 'cat', 'cat', 'dog', 'cat', 'dog', 'cat', 'cat', 'cat', 'dog', 'dog', 'dog', 'cat', 'cat', 'cat', 'cat', 'dog', 'cat', 'cat', 'dog', 'dog', 'dog', 'dog', 'cat', 'dog', 'dog', 'dog', 'cat', 'cat', 'cat', 'dog', 'cat', 'cat', 'dog', 'cat', 'dog', 'dog', 'cat', 'cat', 'dog', 'cat', 'dog', 'cat', 'cat', 'dog', 'dog', 'cat', 'dog', 'cat', 'dog', 'dog', 'dog', 'dog', 'dog', 'cat', 'cat', 'dog', 'dog', 'dog', 'cat', 'dog', 'dog', 'dog', 'cat', 'dog', 'dog', 'cat', 'dog', 'dog', 'dog', 'cat', 'dog', 'dog', 'cat', 'dog', 'cat', 'dog', 'cat', 'cat', 'dog', 'cat', 'dog', 'dog', 'dog', 'dog', 'cat', 'cat', 'dog', 'cat', 'cat', 'cat', 'dog', 'dog', 'cat', 'dog', 'cat', 'dog', 'dog', 'cat', 'dog', 'dog', 'dog', 'dog', 'cat', 'dog', 'cat', 'dog', 'cat', 'dog', 'cat', 'dog', 'dog', 'cat', 'cat', 'cat', 'dog', 'dog', 'dog', 'cat', 'cat', 'dog', 'cat', 'dog', 'cat', 'cat', 'dog', 'dog', 'dog', 'cat', 'cat', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'dog', 'dog', 'dog', 'cat', 'dog', 'cat', 'dog', 'dog', 'cat', 'dog', 'dog', 'cat', 'dog', 'cat', 'cat', 'cat', 'dog', 'cat', 'cat', 'dog', 'cat', 'dog', 'cat', 'cat', 'dog', 'cat', 'dog', 'dog', 'dog', 'dog', 'cat', 'cat', 'dog', 'dog', 'dog', 'dog', 'dog', 'cat', 'dog', 'dog', 'cat', 'cat', 'dog', 'cat', 'dog', 'dog', 'dog', 'cat', 'cat', 'dog', 'cat', 'dog', 'cat', 'cat', 'dog', 'cat', 'dog', 'cat', 'cat', 'dog', 'cat', 'dog', 'dog', 'dog', 'dog', 'cat', 'cat', 'dog', 'dog', 'cat', 'dog', 'cat', 'dog', 'cat', 'cat', 'cat', 'dog', 'cat', 'dog', 'cat', 'dog', 'cat', 'dog', 'dog', 'cat', 'dog', 'cat', 'cat', 'cat', 'dog', 'cat', 'cat', 'cat', 'dog', 'dog', 'dog', 'dog', 'dog', 'cat', 'dog', 'cat', 'dog', 'cat', 'cat', 'cat', 'dog', 'dog', 'cat', 'cat', 'cat', 'cat', 'cat', 'dog', 'cat', 'cat', 'dog', 'cat', 'dog', 'dog', 'dog', 'cat', 'dog', 'dog', 'cat', 'cat', 'cat', 'dog', 'dog', 'dog', 'cat', 'cat', 'dog', 'dog', 'dog', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'dog', 'dog', 'cat', 'dog', 'cat', 'dog', 'cat', 'cat', 'dog', 'cat', 'dog', 'dog', 'dog', 'cat', 'dog', 'dog', 'cat', 'dog', 'dog', 'dog', 'cat', 'cat', 'dog', 'dog', 'cat', 'cat', 'dog', 'cat', 'cat', 'cat', 'dog', 'cat', 'dog', 'dog', 'cat', 'cat', 'cat', 'dog', 'cat', 'dog', 'cat', 'cat', 'dog', 'dog', 'dog', 'cat', 'cat', 'dog', 'dog', 'cat', 'dog', 'dog', 'cat', 'dog', 'dog', 'dog', 'cat', 'cat', 'cat', 'dog', 'dog', 'dog', 'dog', 'cat', 'cat', 'dog', 'cat', 'dog', 'dog', 'dog', 'cat', 'cat', 'cat', 'dog', 'cat', 'dog', 'cat', 'dog', 'dog', 'cat', 'cat', 'cat', 'cat', 'dog', 'cat', 'dog', 'cat', 'cat', 'cat', 'dog', 'dog', 'dog', 'cat', 'cat', 'cat', 'cat', 'dog', 'cat', 'dog', 'dog', 'dog', 'cat', 'dog', 'cat', 'cat', 'cat', 'dog', 'cat', 'dog', 'cat', 'dog', 'dog', 'cat', 'cat', 'dog', 'dog', 'cat', 'cat', 'dog', 'cat', 'dog', 'dog', 'cat', 'cat', 'dog', 'cat', 'cat', 'dog', 'dog', 'dog', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'dog', 'dog', 'dog', 'dog', 'cat', 'dog', 'cat', 'cat', 'dog', 'dog', 'cat', 'dog', 'cat', 'dog', 'dog', 'cat', 'cat', 'cat', 'dog', 'cat', 'dog', 'cat', 'cat', 'dog', 'cat', 'cat', 'dog', 'cat', 'dog', 'dog', 'dog', 'cat', 'dog', 'dog', 'dog', 'cat', 'dog', 'cat', 'dog', 'cat', 'cat', 'dog', 'dog', 'dog', 'cat', 'cat', 'cat', 'dog', 'dog', 'cat', 'dog', 'cat', 'cat', 'cat', 'cat', 'dog', 'cat', 'cat', 'cat', 'dog', 'cat', 'dog', 'cat', 'cat', 'cat', 'cat', 'cat', 'dog', 'cat', 'dog', 'cat', 'cat', 'cat', 'cat', 'cat', 'dog', 'cat', 'dog', 'cat', 'cat', 'dog', 'cat', 'dog', 'cat', 'dog', 'cat', 'cat', 'cat', 'cat', 'cat', 'dog', 'dog', 'cat', 'cat', 'dog', 'dog', 'dog', 'cat', 'cat', 'dog', 'cat', 'cat', 'dog', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'dog', 'c ...
# [1 1 1 ... 1 1 1]

# %%
# Load ảnh và resize về đúng kích thước mà VGG 16 cần là (224,224)
list_image = []
for (j, imagePath) in enumerate(image_path):
    # Load ảnh và resize về kích thước (224, 224)
    image = load_img(imagePath, target_size=(224, 224))
    
    # Chuyển ảnh thành mảng numpy
    image = img_to_array(image)
    
    # Mở rộng chiều của mảng numpy
    image = np.expand_dims(image, 0)
    
    # Tiền xử lý ảnh theo tiêu chuẩn của mô hình VGG16
    image = imagenet_utils.preprocess_input(image)
    
    # Thêm ảnh đã tiền xử lý vào danh sách
    list_image.append(image)
    
# Chuyển danh sách các ảnh thành mảng numpy một chiều
list_image = np.vstack(list_image)

# %%
print(list_image)
# Out:
# [[[[ 1.2006100e+02  1.0322100e+02  9.5320000e+01]
#    [ 8.8060997e+01  7.3221001e+01  6.6320000e+01]
#    [-8.9390030e+00 -2.1778999e+01 -2.8680000e+01]
#    ...
#    [ 3.5060997e+01  1.0221001e+01 -6.8000031e-01]
#    [ 1.3006100e+02  1.0522100e+02  9.2320000e+01]
#    [ 1.2906100e+02  1.0522100e+02  9.0320000e+01]]
#
#   [[ 1.6060997e+01  2.2100067e-01 -4.6800003e+00]
#    [ 7.0060997e+01  5.6221001e+01  5.3320000e+01]
#    [ 1.0060997e+01 -3.7789993e+00 -6.6800003e+00]
#    ...
#    [ 5.2060997e+01  2.7221001e+01  1.6320000e+01]
#    [ 7.9060997e+01  5.6221001e+01  4.2320000e+01]
#    [-1.8939003e+01 -4.0778999e+01 -5.6680000e+01]]
#
#   [[ 6.6060997e+01  5.2221001e+01  5.4320000e+01]
#    [ 3.8060997e+01  2.6221001e+01  2.9320000e+01]
#    [-9.3900299e-01 -1.3778999e+01 -8.6800003e+00]
#    ...
#    [ 6.6060997e+01  4.2221001e+01  3.1320000e+01]
#    [ 6.0997009e-02 -2.0778999e+01 -3.4680000e+01]
#    [ 1.1106100e+02  9.1221001e+01  7.5320000e+01]]
 1.5106100e+02  1.3822101e+02  1.3132001e+02]
#    [ 1.5106100e+02  1.3822101e+02  1.3132001e+02]
#    [ 1.5106100e+02  1.3822101e+02  1.3132001e+02]
#    ...
#    [ 1.5106100e+02  1.3822101e+02  1.3132001e+02]
#    [ 9.9060997e+01  8.1221001e+01  7.5320000e+01]
#    [-2.9939003e+01 -4.7778999e+01 -5.3680000e+01]]]
#
#
#  [[[-6.3939003e+01 -7.0778999e+01 -7.0680000e+01]
#    [-6.6939003e+01 -7.1778999e+01 -7.1680000e+01]
#    [-5.7939003e+01 -6.2778999e+01 -6.2680000e+01]
#    ...
#    [-7.6939003e+01 -9.7778999e+01 -9.7680000e+01]
#    [-8.8939003e+01 -1.0577900e+02 -1.0168000e+02]
#    [-9.0939003e+01 -1.0577900e+02 -1.0068000e+02]]
#
#   [[-5.9939003e+01 -6.7778999e+01 -6.5680000e+01]
#    [-6.3939003e+01 -6.9778999e+01 -6.7680000e+01]
#    [-6.0939003e+01 -6.6778999e+01 -6.4680000e+01]
#    ...
#    [-8.5939003e+01 -1.0577900e+02 -1.0568000e+02]
#    [-8.5939003e+01 -1.0277900e+02 -9.8680000e+01]
#    [-8.7939003e+01 -1.0177900e+02 -9.8680000e+01]]
#
#   [[-6.3939003e+01 -7.1778999e+01 -6.9680000e+01]
#    [-6.0939003e+01 -6.6778999e+01 -6.4680000e+01]
#    [-6.0939003e+01 -6.6778999e+01 -6.4680000e+01]
#    ...
#    [-8.1939003e+01 -9.8778999e+01 -9.9680000e+01]
#    [-8.0939003e+01 -9.7778999e+01 -9.3680000e+01]
#    [-8.2939003e+01 -9.6778999e+01 -9.3680000e+01]]
#
#   ...
#
#   [[ 1.7060997e+01  2.2210007e+00 -5.6800003e+00]
#    [ 1.1060997e+01  1.2210007e+00 -7.6800003e+00]
#    [ 1.0060997e+01  4.2210007e+00 -5.6800003e+00]
#    ...
#    [-7.0939003e+01 -9.7778999e+01 -1.0068000e+02]
#    [-7.4939003e+01 -9.5778999e+01 -1.0168000e+02]
#    [-7.8939003e+01 -9.7778999e+01 -1.0368000e+02]]
#
#   [[ 2.2060997e+01  7.2210007e+00 -6.8000031e-01]
#    [ 1.9060997e+01  9.2210007e+00  3.1999969e-01]
#    [ 1.7060997e+01  1.1221001e+01  1.3199997e+00]
#    ...
#    [-7.2939003e+01 -9.9778999e+01 -1.0268000e+02]
#    [-7.4939003e+01 -9.5778999e+01 -1.0168000e+02]
#    [-7.7939003e+01 -9.6778999e+01 -1.0268000e+02]]
#
#   [[ 2.2060997e+01  7.2210007e+00 -6.8000031e-01]
#    [ 1.6060997e+01  6.2210007e+00 -2.6800003e+00]
#    [ 7.0609970e+00  1.2210007e+00 -8.6800003e+00]
#    ...
#    [-6.9939003e+01 -9.6778999e+01 -9.9680000e+01]
#    [-7.3939003e+01 -9.4778999e+01 -1.0068000e+02]
#    [-7.7939003e+01 -9.6778999e+01 -1.0268000e+02]]]]

# %%
X_train, X_test, y_train, y_test = train_test_split(list_image, labels, test_size=0.2, random_state=42)

# %% [markdown]
# #### Xây dựng Model

# %%
from keras.layers import Input, Conv2D, BatchNormalization, Activation, Add, MaxPooling2D, Flatten, Dense
from keras.models import Model

def residual_block(input_tensor, filters, kernel_size=(3, 3), strides=(1, 1), activation='relu'):
    x = Conv2D(filters, kernel_size, strides=strides, padding='same')(input_tensor)
    x = BatchNormalization()(x)
    x = Activation(activation)(x)
    x = Conv2D(filters, kernel_size, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation(activation)(x)
    x = Add()([x, input_tensor])
    x = Activation(activation)(x)
    return x

input_tensor = Input(shape=(X_train.shape[1:]))
x = Conv2D(32, (3, 3), activation='relu')(input_tensor)
x = MaxPooling2D(pool_size=(2, 2))(x)

# Building Residual blocks
for _ in range(3):  # Example: 3 residual blocks
    x = residual_block(x, 32)

x = MaxPooling2D(pool_size=(2, 2))(x)
x = Flatten()(x)
x = Dense(128, activation='relu')(x)
output = Dense(2, activation='softmax')(x)

model = Model(inputs=input_tensor, outputs=output)

# %% [markdown]
# #### Fit model

# %%
# Tạo đối tượng optimizer
optimizer = tf.keras.optimizers.Adam()

# Thiết lập ModelCheckpoint
save_best_only = True
checkpoint = ModelCheckpoint('models/model-ResNet50-{epoch:03d}.keras',  
                             monitor='val_loss',
                             verbose=1,
                             save_best_only=save_best_only,
                             mode='auto')

# Xây dựng quy trình huấn luyện
model.compile(optimizer=optimizer,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Huấn luyện mô hình với dữ liệu đã chuẩn bị
H = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2, callbacks=[checkpoint])
# Out:
# Epoch 1/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 924ms/step - accuracy: 0.5377 - loss: 297.6519
# Epoch 1: val_loss improved from inf to 20.03924, saving model to models/model-ResNet50-001.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.5379 - loss: 295.8477 - val_accuracy: 0.5813 - val_loss: 20.0392
# Epoch 2/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 923ms/step - accuracy: 0.6779 - loss: 14.2795
# Epoch 2: val_loss improved from 20.03924 to 11.03250, saving model to models/model-ResNet50-002.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 100s 998ms/step - accuracy: 0.6778 - loss: 14.2852 - val_accuracy: 0.6212 - val_loss: 11.0325
# Epoch 3/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 914ms/step - accuracy: 0.7333 - loss: 8.9091
# Epoch 3: val_loss improved from 11.03250 to 9.42695, saving model to models/model-ResNet50-003.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 98s 983ms/step - accuracy: 0.7335 - loss: 8.8926 - val_accuracy: 0.6463 - val_loss: 9.4269
# Epoch 4/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 919ms/step - accuracy: 0.8099 - loss: 3.7918
# Epoch 4: val_loss improved from 9.42695 to 8.48336, saving model to models/model-ResNet50-004.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 98s 982ms/step - accuracy: 0.8097 - loss: 3.7947 - val_accuracy: 0.6263 - val_loss: 8.4834
# Epoch 5/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 908ms/step - accuracy: 0.8252 - loss: 3.1347
# Epoch 5: val_loss improved from 8.48336 to 8.13835, saving model to models/model-ResNet50-005.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 96s 964ms/step - accuracy: 0.8251 - loss: 3.1381 - val_accuracy: 0.6625 - val_loss: 8.1383
# Epoch 6/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 916ms/step - accuracy: 0.8174 - loss: 3.6808
# Epoch 6: val_loss did not improve from 8.13835
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 97s 967ms/step - accuracy: 0.8176 - loss: 3.6752 - val_accuracy: 0.6000 - val_loss: 10.5010
# Epoch 7/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 893ms/step - accuracy: 0.8137 - loss: 3.9047
# Epoch 7: val_loss improved from 8.13835 to 7.19380, saving model to models/model-ResNet50-007.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 95s 946ms/step - accuracy: 0.8138 - loss: 3.9032 - val_accuracy: 0.6650 - val_loss: 7.1938
# Epoch 8/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 909ms/step - accuracy: 0.8413 - loss: 3.2676
# Epoch 8: val_loss did not improve from 7.19380
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 96s 960ms/step - accuracy: 0.8414 - loss: 3.2632 - val_accuracy: 0.6288 - val_loss: 13.0099
# Epoch 9/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 890ms/step - accuracy: 0.9005 - loss: 1.3722
# Epoch 9: val_loss did not improve from 7.19380
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 94s 940ms/step - accuracy: 0.9005 - loss: 1.3724 - val_accuracy: 0.6612 - val_loss: 8.2818
# Epoch 10/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 976ms/step - accuracy: 0.9409 - loss: 0.5640
# Epoch 10: val_loss did not improve from 7.19380
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 103s 1s/step - accuracy: 0.9410 - loss: 0.5632 - val_accuracy: 0.6263 - val_loss: 9.5371

# %%
# Vẽ đồ thị loss, accuracy của traning set và validation set
fig = plt.figure()
numOfEpoch = 10
plt.plot(np.arange(0, numOfEpoch), H.history['loss'], label='training loss')
plt.plot(np.arange(0, numOfEpoch), H.history['val_loss'], label='validation loss')
plt.plot(np.arange(0, numOfEpoch), H.history['accuracy'], label='accuracy') # sử dụng từ khóa accuracy thay vì acc
plt.plot(np.arange(0, numOfEpoch), H.history['val_accuracy'], label='validation accuracy') # sử dụng từ khóa val_accuracy thay vì val_acc
plt.title('Accuracy and Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss|Accuracy')
plt.legend()

# %%
# from keras.models import load_model
# model = load_model('models/model-ResNet50-008.keras')

score = model.evaluate(X_test, y_test, verbose=1)
print(score)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 214ms/step - accuracy: 0.7366 - loss: 9.7837
# [9.997036933898926, 0.734000027179718]

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 222, 222,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 111, 111,  │          0 │ conv2d[0][0]      │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 111, 111,  │      9,248 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 111, 111,  │        128 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 111, 111,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 111, 111,  │      9,248 │ activation[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 111, 111,  │        128 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 111, 111,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 111, 111,  │          0 │ activation_1[0][… │
# │                     │ 32)               │            │ max_pooling2d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 111, 111,  │          0 │ add[0][0]         │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 111, 111,  │      9,248 │ activation_2[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 111, 111,  │        128 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 111, 111,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 111, 111,  │      9,248 │ activation_3[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 111, 111,  │        128 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 111, 111,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 111, 111,  │          0 │ activation_4[0][… │
# │                     │ 32)               │            │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 111, 111,  │          0 │ add_1[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 111, 111,  │      9,248 │ activation_5[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 111, 111,  │        128 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 111, 111,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 111, 111,  │      9,248 │ activation_6[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 111, 111,  │        128 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 111, 111,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 111, 111,  │          0 │ activation_7[0][… │
# │                     │ 32)               │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 111, 111,  │          0 │ add_2[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 55, 55,    │          0 │ activation_8[0][… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 96800)     │          0 │ max_pooling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │ 12,390,528 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 10)        │      1,290 │ dense[0][0]       │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 37,346,144 (142.46 MB)
#  Trainable params: 12,448,586 (47.49 MB)
#  Non-trainable params: 384 (1.50 KB)
#  Optimizer params: 24,897,174 (94.98 MB)

# %%
# Đánh giá model
preds = model.predict(X_test) # DỰ ĐOÁN VÀ ĐÁNH GIÁ 
preds = np.argmax(preds, axis=1)
print(classification_report(y_test, preds))
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 222ms/step
#               precision    recall  f1-score   support
#
#            0       0.80      0.64      0.71       510
#            1       0.69      0.83      0.75       490
#
#     accuracy                           0.73      1000
#    macro avg       0.74      0.74      0.73      1000
# weighted avg       0.75      0.73      0.73      1000

# %%
# 10. Dự đoán ảnh
plt.imshow(X_test[0])
plt.axis('off')  
plt.show()

y_predict = model.predict(np.expand_dims(X_test[0], axis=0))
print('Giá trị dự đoán: ', np.argmax(y_predict))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Giá trị dự đoán:  1

# %%
# Tạo ma trận nhầm lẫn
cm = confusion_matrix(y_test, preds)

# Chuyển nhãn số thành tên 
label_names = le.inverse_transform(np.unique(y_test))
label_names = [label.split('/')[-1] for label in label_names]
# Sắp xếp lại ma trận nhầm lẫn
sorted_cm = cm[np.argsort(label_names)][:, np.argsort(label_names)]

# Tạo dataframe từ ma trận nhầm lẫn đã sắp xếp lại
df_cm = pd.DataFrame(sorted_cm, index=label_names, columns=label_names)

# Vẽ ma trận nhầm lẫn
plt.figure(figsize=(10, 8))
sns.heatmap(df_cm, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.show()
