# %% [markdown]
# ## Init

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !pip install -q efficientnet

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# import seaborn as sns
# import pickle
import scipy.io
import tarfile
# import csv
# # import sys
import os
import tensorflow as tf
# import tensorflow.keras as keras
import tensorflow.keras.models as M
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
import tensorflow.keras.callbacks as C
# from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import (
    LearningRateScheduler,
    ModelCheckpoint,
    EarlyStopping
)
# from tensorflow.keras.callbacks import Callback
from tensorflow.keras import optimizers
import efficientnet.tfkeras as efn
from sklearn.model_selection import train_test_split
import PIL
# from PIL import ImageOps, ImageFilter

# %%
os.chdir("/content/drive/MyDrive/3_XuLyAnh_Flowers")
os.getcwd()
# Out:
# '/content/drive/.shortcut-targets-by-id/1tU35xhAZwBdemxnc1j9Q3JzeU3wbyFMK/3_XuLyAnh_Flowers'

# %%
EPOCHS        = 5
BATCH_SIZE    = 8
LR_step1      = 1e-3
LR_step2      = 1e-4
LR_step3      = 1e-5
VAL_SPLIT     = 0.2
CLASS_NUM     = 15       #102
IMG_SIZE      = 250    # (725*500)
IMG_CHANNELS  = 3
input_shape   = (IMG_SIZE, IMG_SIZE, IMG_CHANNELS)
RANDOM_SEED   = 42

# %% [markdown]
# ## Data

# %% [markdown]
# ### Load Data

# %%
# # Đường dẫn đến tệp .tgz cần giải nén
# file_path = os.path.join(os.getcwd(), '102flowers.tgz')

# # Mở tệp .tgz
# with tarfile.open(file_path, 'r:gz') as tar:
#     # Giải nén toàn bộ nội dung của tệp .tgz vào thư mục hiện tại
#     tar.extractall()

# %%
DATA_PATH = os.getcwd()
PATH = os.getcwd() + "/jpg/"

# %%
def get_all_filenames(tar_fn):
    with tarfile.open(tar_fn) as f:
        return [m.name for m in f.getmembers() if m.isfile()]


df = pd.DataFrame()
df['Id'] = sorted(get_all_filenames(DATA_PATH + '/102flowers.tgz'))

# load file label:  label (1 -> 102) == -1 ==>  (0 -> 101)
df['Category'] = scipy.io.loadmat(DATA_PATH + '/imagelabels.mat')['labels'][0] - 1
df['Category'] = df['Category'].astype(str)

# %%
top_15_categories = ['48', '76', '42', '72', '89', '73', '81', '95', '88', '77', '37', '39', '83', '96', '74']

# %%
# Lọc DataFrame ban đầu
df_15 = df[df['Category'].isin(top_15_categories)]

# %%
# df.head(5)

# %% [markdown]
# ### Visualization Data

# %%
# Đoạn mã để đếm giá trị của cột "Category" và vẽ biểu đồ cột
df_15['Category'].value_counts().plot(kind='bar')
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Count of Each Category')
plt.show()

# %%
# # Đoạn mã để đếm giá trị của cột "Category" và vẽ biểu đồ cột
# df['Category'].value_counts().plot(kind='bar')
# plt.xlabel('Category')
# plt.ylabel('Count')
# plt.title('Count of Each Category')
# plt.show()

# %%
print(f"Có {df_15['Category'].nunique()} loài hoa")
print("Giá trị lớn nhất của cột 'Category':", df['Category'].value_counts().max())
print("Giá trị nhỏ nhất của cột 'Category':", df['Category'].value_counts().min())
# Out:
# Có 15 loài hoa
# Giá trị lớn nhất của cột 'Category': 258
# Giá trị nhỏ nhất của cột 'Category': 40

# %%
# print(f"Có {df['Category'].nunique()} loài hoa")
# print("Giá trị lớn nhất của cột 'Category':", df['Category'].value_counts().max())
# print("Giá trị nhỏ nhất của cột 'Category':", df['Category'].value_counts().min())

# %%
df_15['Category'].unique()   # giá trị từ 1 đến 101
# Out:
# array(['76', '72', '88', '73', '81', '77', '74', '42', '83', '89', '39',
#        '37', '48', '95', '96'], dtype=object)

# %%
# df['Category'].unique()   # giá trị từ 1 đến 101

# %%
PATH = os.getcwd() + "/"

# %%
print('Random Sample')
plt.figure(figsize = (12, 8))
random_image = df_15.sample(n = 9)
random_image_paths = random_image['Id'].values
random_image_cat = random_image['Category'].values

for index, path in enumerate(random_image_paths):
    im = PIL.Image.open(PATH + path)
    plt.subplot(3, 3, index + 1)
    plt.imshow(im)
    plt.title('Class: ' + str(random_image_cat[index]))
    plt.axis('off')

plt.show()
# Out:
# Random Sample

# %%
# print('Random Sample')
# plt.figure(figsize = (12, 8))
# random_image = df.sample(n = 9)
# random_image_paths = random_image['Id'].values
# random_image_cat = random_image['Category'].values

# for index, path in enumerate(random_image_paths):
#     im = PIL.Image.open(PATH + path)
#     plt.subplot(3, 3, index + 1)
#     plt.imshow(im)
#     plt.title('Class: ' + str(random_image_cat[index]))
#     plt.axis('off')

# plt.show()

# %%
image = PIL.Image.open(PATH + path)
imgplot = plt.imshow(image)
plt.show()
image.size
# Out:
# (700, 500)

# %% [markdown]
# ### Split Train Test

# %%
train_files, test_files, train_labels, test_labels = \
    train_test_split(
        df_15['Id'],
        df_15['Category'],
        test_size = 0.2,
        random_state = 42,
        stratify = df_15['Category']
)
train_files = pd.DataFrame(train_files)
test_files = pd.DataFrame(test_files)
train_files['Category'] = train_labels
test_files['Category'] = test_labels
train_files.shape, test_files.shape
# Out:
# ((1436, 2), (360, 2))

# %%
# train_files, test_files, train_labels, test_labels = \
#     train_test_split(
#         df['Id'],
#         df['Category'],
#         test_size = 0.2,
#         random_state = 42,
#         stratify = df['Category']
# )
# train_files = pd.DataFrame(train_files)
# test_files = pd.DataFrame(test_files)
# train_files['Category'] = train_labels
# test_files['Category'] = test_labels
# train_files.shape, test_files.shape

# %%
train_files.head(5)
# Out:
#                        Id Category
# 270   jpg/image_00271.jpg       72
# 6223  jpg/image_06224.jpg       48
# 263   jpg/image_00264.jpg       72
# 6210  jpg/image_06211.jpg       48
# 7678  jpg/image_07679.jpg       95

# %%
# Đoạn mã để đếm giá trị của cột "Category" và vẽ biểu đồ cột
train_files['Category'].value_counts().plot(kind='bar')
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Count of Each Category on Train Data')
plt.show()

# %%
# Đoạn mã để đếm giá trị của cột "Category" và vẽ biểu đồ cột
test_files['Category'].value_counts().plot(kind='bar')
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Count of Each Category on Test Data')
plt.show()

# %% [markdown]
# ### Data augmentation

# %%
train_datagen = ImageDataGenerator(
    rescale = 1. / 255,
    rotation_range = 50,
    shear_range = 0.2,
    zoom_range = [0.75, 1.25],
    brightness_range = [0.5, 1.5],
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    horizontal_flip = True
)
test_datagen = ImageDataGenerator(rescale = 1. / 255)

# %%
train_generator = train_datagen.flow_from_dataframe(
    dataframe = train_files,
    directory = DATA_PATH,
    x_col = 'Id',
    y_col = 'Category',
    target_size = (IMG_SIZE, IMG_SIZE),
    batch_size = BATCH_SIZE,
    class_mode = 'categorical',
    shuffle = True,
    seed = RANDOM_SEED
)
test_generator = test_datagen.flow_from_dataframe(
    dataframe = test_files,
    directory = DATA_PATH,
    x_col = 'Id',
    y_col = 'Category',
    target_size = (IMG_SIZE, IMG_SIZE),
    batch_size = BATCH_SIZE,
    class_mode = 'categorical',
    shuffle = False,
    seed = RANDOM_SEED
)
# Out:
# Found 1436 validated image filenames belonging to 15 classes.
# Found 360 validated image filenames belonging to 15 classes.

# %%
from skimage import io

def imshow(image_RGB):
    io.imshow(image_RGB)
    io.show()

x, y = train_generator.next()
print('Ví dụ về hình ảnh từ train_generator')
plt.figure(figsize = (12, 8))

for i in range(0, 6):
    image = x[i]
    plt.subplot(3, 3, i + 1)
    plt.imshow(image)
#     plt.title('Class: ' + str(y[i]))
#     plt.axis('off')

plt.show()
# Out:
# Ví dụ về hình ảnh từ train_generator

# %%
x, y = test_generator.next()
print('Ví dụ về hình ảnh từ test_generator')
plt.figure(figsize = (12, 8))

for i in range(0, 6):
    image = x[i]
    plt.subplot(3, 3, i + 1)
    plt.imshow(image)
#     plt.title('Class: ' + str(y[i]))
#     plt.axis('off')

plt.show()
# Out:
# Ví dụ về hình ảnh từ test_generator

# %% [markdown]
# ## Model Lenet5

# %% [markdown]
# ### Lenet5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
lenet5_model = M.Sequential()
lenet5_model.add(L.Conv2D(6, 5, activation='tanh', input_shape=input_shape))
lenet5_model.add(L.AveragePooling2D(2))
lenet5_model.add(L.Activation('sigmoid'))
lenet5_model.add(L.Conv2D(16, 5, activation='tanh'))
lenet5_model.add(L.AveragePooling2D(2))
lenet5_model.add(L.Activation('sigmoid'))
lenet5_model.add(L.Conv2D(6, 5, activation='tanh'))
lenet5_model.add(L.Flatten())
lenet5_model.add(L.Dense(2048, activation='tanh'))
# lenet5_model.add(L.Dense(10, activation='softmax'))

# %%
# Print model summary
lenet5_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 246, 246, 6)       456
#
#  average_pooling2d (Average  (None, 123, 123, 6)       0
#  Pooling2D)
#
#  activation (Activation)     (None, 123, 123, 6)       0
#
#  conv2d_1 (Conv2D)           (None, 119, 119, 16)      2416
#
#  average_pooling2d_1 (Avera  (None, 59, 59, 16)        0
#  gePooling2D)
#
#  activation_1 (Activation)   (None, 59, 59, 16)        0
#
#  conv2d_2 (Conv2D)           (None, 55, 55, 6)         2406
#
#  flatten (Flatten)           (None, 18150)             0
#
#  dense (Dense)               (None, 2048)              37173248
#
# =================================================================
# Total params: 37178526 (141.82 MB)
# Trainable params: 37178526 (141.82 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model = M.Sequential()
model.add(lenet5_model)
# model.add(L.GlobalAveragePooling2D())
model.add(L.Dense(CLASS_NUM, activation = 'softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 2048)              37178526
#
#  dense_1 (Dense)             (None, 15)                30735
#
# =================================================================
# Total params: 37209261 (141.94 MB)
# Trainable params: 37209261 (141.94 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
print(len(model.layers))
print(len(model.trainable_variables))
# Out:
# 2
# 10

# %%
# check the trainable status of the individual layers
for layer in model.layers:
    print(layer, layer.trainable)
# Out:
# <keras.src.engine.sequential.Sequential object at 0x7b75f92a91b0> True
# <keras.src.layers.core.dense.Dense object at 0x7b75f930f820> True

# %%
model.compile(
    loss = 'categorical_crossentropy',
    optimizer = optimizers.Adam(learning_rate = LR_step1),
    metrics = ['accuracy']
)

# %% [markdown]
# earlystop:
# - monitor - giám sát trên thang đo val_acc
# - patience - số lượng epochs không cải thiện độ chính xác sẽ dừng
# - restore_best_weights - quay lại trọng số cho độ chính xác tốt nhất

# %%
checkpoint = ModelCheckpoint(
    'best_model_test.hdf5',
    monitor = ['val_accuracy'],
    verbose = 1,
    mode = 'max'
)
earlystop = EarlyStopping(
    monitor = 'val_accuracy',
    patience = 10,
    restore_best_weights = True
)
callbacks_list = [checkpoint, earlystop]

# %%
# scores = model.evaluate(test_generator, verbose=1)
# print('Accuracy: %.2f%%' % (scores[1] * 100))

# %% [markdown]
# ### Huấn luyện

# %% [markdown]
# đã huấn luyện được 12 epoch

# %%
# fit include generator
history = model.fit(
    train_generator,
    steps_per_epoch = train_generator.samples // train_generator.batch_size,
    validation_data = test_generator,
    validation_steps = test_generator.samples // test_generator.batch_size,
    epochs = 50,
    callbacks = callbacks_list
)
# Out:
# Epoch 1/50
# 179/179 [==============================] - ETA: 0s - loss: 4.3194 - accuracy: 0.0973
# Epoch 1: saving model to best_model_test.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 179/179 [==============================] - 987s 5s/step - loss: 4.3194 - accuracy: 0.0973 - val_loss: 3.1638 - val_accuracy: 0.1028
# Epoch 2/50
# 179/179 [==============================] - ETA: 0s - loss: 3.2289 - accuracy: 0.0924
# Epoch 2: saving model to best_model_test.hdf5
# 179/179 [==============================] - 41s 228ms/step - loss: 3.2289 - accuracy: 0.0924 - val_loss: 3.1067 - val_accuracy: 0.1389
# Epoch 3/50
# 179/179 [==============================] - ETA: 0s - loss: 3.1929 - accuracy: 0.0917
# Epoch 3: saving model to best_model_test.hdf5
# 179/179 [==============================] - 40s 226ms/step - loss: 3.1929 - accuracy: 0.0917 - val_loss: 3.4402 - val_accuracy: 0.0722
# Epoch 4/50
# 179/179 [==============================] - ETA: 0s - loss: 3.2343 - accuracy: 0.0903
# Epoch 4: saving model to best_model_test.hdf5
# 179/179 [==============================] - 43s 238ms/step - loss: 3.2343 - accuracy: 0.0903 - val_loss: 3.2831 - val_accuracy: 0.0722
# Epoch 5/50
# 179/179 [==============================] - ETA: 0s - loss: 3.1885 - accuracy: 0.0896
# Epoch 5: saving model to best_model_test.hdf5
# 179/179 [==============================] - 42s 234ms/step - loss: 3.1885 - accuracy: 0.0896 - val_loss: 3.2914 - val_accuracy: 0.1389
# Epoch 6/50
# 179/179 [==============================] - ETA: 0s - loss: 3.1995 - accuracy: 0.0882
# Epoch 6: saving model to best_model_test.hdf5
# 179/179 [==============================] - 41s 229ms/step - loss: 3.1995 - accuracy: 0.0882 - val_loss: 3.2714 - val_accuracy: 0.1083
# Epoch 7/50
# 179/179 [==============================] - ETA: 0s - loss: 3.2234 - accuracy: 0.1036
# Epoch 7: saving model to best_model_test.hdf5
# 179/179 [==============================] - 41s 229ms/step - loss: 3.2234 - accuracy: 0.1036 - val_loss: 3.1763 - val_accuracy: 0.0472
# Epoch 8/50
# 179/179 [==============================] - ETA: 0s - loss: 3.2210 - accuracy: 0.0973
# Epoch 8: saving model to best_model_test.hdf5
# 179/179 [==============================] - 41s 226ms/step - loss: 3.2210 - accuracy: 0.0973 - val_loss: 3.3360 - val_accuracy: 0.0667
# Epoch 9/50
# 179/179 [==============================] - ETA: 0s - loss: 3.1630 - accuracy: 0.1064
# Epoch 9: saving model to best_model_test.hdf5
# 179/179 [==============================] - 40s 224ms/step - loss: 3.1630 - accuracy: 0.1064 - val_loss: 2.7370 - val_accuracy: 0.1389
# Epoch 10/50
# 179/179 [==============================] - ETA: 0s - loss: 3.2471 - accuracy: 0.0868
# Epoch 10: saving model to best_model_test.hdf5
# 179/179 [==============================] - 40s 225ms/step - loss: 3.2471 - accuracy: 0.0868 - val_loss: 3.2952 - val_accuracy: 0.1028
# Epoch 11/50
# 179/179 [==============================] - ETA: 0s - loss: 3.2196 - accuracy: 0.1036
# Epoch 11: saving model to best_model_test.hdf5
# 179/179 [==============================] - 41s 227ms/step - loss: 3.2196 - accuracy: 0.1036 - val_loss: 2.9837 - val_accuracy: 0.1389
# Epoch 12/50
# 179/179 [==============================] - ETA: 0s - loss: 3.1370 - accuracy: 0.0938
# Epoch 12: saving model to best_model_test.hdf5
# 179/179 [==============================] - 43s 240ms/step - loss: 3.1370 - accuracy: 0.0938 - val_loss: 3.4034 - val_accuracy: 0.1083

# %%
model.save('./SaveModel/model_lenet5_step1.hdf5')
# model.load_weights('best_model_test.hdf5')

# %% [markdown]
# ## Cur

# %%
# scores = model.evaluate_generator(test_generator, verbose = 1)
scores = model.evaluate(test_generator, verbose=1)
print('Accuracy: %.2f%%' % (scores[1] * 100))
# Out:
# 45/45 [==============================] - 2s 46ms/step - loss: 3.1067 - accuracy: 0.1389
# Accuracy: 13.89%

# %%
def plot_history(history):
    plt.figure(figsize = (10, 5))
#     plt.style.use('dark_background')
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(len(acc))
    plt.plot(epochs, acc, 'b', label = 'Training acc')
    plt.plot(epochs, val_acc, 'g', label = 'Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()
#     plt.figure()
    plt.figure(figsize = (10, 5))
#     plt.style.use('dark_background')
    plt.plot(epochs, loss, 'b', label = 'Training loss')
    plt.plot(epochs, val_loss, 'g', label = 'Validation loss')
    plt.title('Training and validation loss')
    plt.legend()
    plt.show()

# %%
plot_history(history)

# %% [markdown]
# ## Model AlexNet

# %% [markdown]
# ### AlexNet

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
model_alexnet = M.Sequential()
model_alexnet.add(L.experimental.preprocessing.Resizing(224, 224, interpolation="bilinear", input_shape=input_shape))
model_alexnet.add(L.Conv2D(96, 11, strides=4, padding='same'))
model_alexnet.add(L.Lambda(tf.nn.local_response_normalization))
model_alexnet.add(L.Activation('relu'))
model_alexnet.add(L.MaxPooling2D(3, strides=2))
model_alexnet.add(L.Conv2D(256, 5, strides=4, padding='same'))
model_alexnet.add(L.Lambda(tf.nn.local_response_normalization))
model_alexnet.add(L.Activation('relu'))
model_alexnet.add(L.MaxPooling2D(3, strides=2))
model_alexnet.add(L.Conv2D(384, 3, strides=4, padding='same'))
model_alexnet.add(L.Activation('relu'))
model_alexnet.add(L.Conv2D(384, 3, strides=4, padding='same'))
model_alexnet.add(L.Activation('relu'))
model_alexnet.add(L.Conv2D(256, 3, strides=4, padding='same'))
model_alexnet.add(L.Activation('relu'))
model_alexnet.add(L.Flatten())
model_alexnet.add(L.Dense(4096, activation='relu'))
model_alexnet.add(L.Dropout(0.5))
model_alexnet.add(L.Dense(4096, activation='relu'))
model_alexnet.add(L.Dropout(0.5))
model_alexnet.add(L.Dense(10, activation='softmax'))
model_alexnet.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resizing (Resizing)         (None, 224, 224, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 56, 56, 96)        34944
#
#  lambda (Lambda)             (None, 56, 56, 96)        0
#
#  activation_2 (Activation)   (None, 56, 56, 96)        0
#
#  max_pooling2d (MaxPooling2  (None, 27, 27, 96)        0
#  D)
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 256)         614656
#
#  lambda_1 (Lambda)           (None, 7, 7, 256)         0
#
#  activation_3 (Activation)   (None, 7, 7, 256)         0
#
#  max_pooling2d_1 (MaxPoolin  (None, 3, 3, 256)         0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 1, 1, 384)         885120
#
#  activation_4 (Activation)   (None, 1, 1, 384)         0
#
#  conv2d_6 (Conv2D)           (None, 1, 1, 384)         1327488
#
#  activation_5 (Activation)   (None, 1, 1, 384)         0
#
#  conv2d_7 (Conv2D)           (None, 1, 1, 256)         884992
#
#  activation_6 (Activation)   (None, 1, 1, 256)         0
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 4096)              1052672
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_3 (Dense)             (None, 4096)              16781312
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_4 (Dense)             (None, 10)                40970
#
# =================================================================
# Total params: 21622154 (82.48 MB)
# Trainable params: 21622154 (82.48 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model = M.Sequential()
model.add(model_alexnet)
# model.add(L.GlobalAveragePooling2D())
model.add(L.Dense(CLASS_NUM, activation = 'softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_2 (Sequential)   (None, 10)                21622154
#
#  dense_5 (Dense)             (None, 15)                165
#
# =================================================================
# Total params: 21622319 (82.48 MB)
# Trainable params: 21622319 (82.48 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
print(len(model.layers))
print(len(model.trainable_variables))
# Out:
# 2
# 18

# %%
# check the trainable status of the individual layers
for layer in model.layers:
    print(layer, layer.trainable)
# Out:
# <keras.src.engine.sequential.Sequential object at 0x7b75f0207d30> True
# <keras.src.layers.core.dense.Dense object at 0x7b75f025fd60> True

# %%
model.compile(
    loss = 'categorical_crossentropy',
    optimizer = optimizers.Adam(learning_rate = LR_step1),
    metrics = ['accuracy']
)

# %% [markdown]
# ### Huấn luyện

# %%
checkpoint = ModelCheckpoint(
    'best_model_test_2.hdf5',
    monitor = ['val_accuracy'],
    verbose = 1,
    mode = 'max'
)
earlystop = EarlyStopping(
    monitor = 'val_accuracy',
    patience = 10,
    restore_best_weights = True
)
callbacks_list = [checkpoint, earlystop]

# %%
# fit include generator
history = model.fit(
    train_generator,
    steps_per_epoch = train_generator.samples // train_generator.batch_size,
    validation_data = test_generator,
    validation_steps = test_generator.samples // test_generator.batch_size,
    epochs = 50,
    callbacks = callbacks_list
)
# Out:
# Epoch 1/50
# 179/179 [==============================] - ETA: 0s - loss: 2.6716 - accuracy: 0.1141
# Epoch 1: saving model to best_model_test_2.hdf5
# 179/179 [==============================] - 55s 268ms/step - loss: 2.6716 - accuracy: 0.1141 - val_loss: 2.6515 - val_accuracy: 0.1083
# Epoch 2/50
# 179/179 [==============================] - ETA: 0s - loss: 2.6421 - accuracy: 0.1317
# Epoch 2: saving model to best_model_test_2.hdf5
# 179/179 [==============================] - 39s 220ms/step - loss: 2.6421 - accuracy: 0.1317 - val_loss: 2.6289 - val_accuracy: 0.1389
# Epoch 3/50
# 179/179 [==============================] - ETA: 0s - loss: 2.6261 - accuracy: 0.1380
# Epoch 3: saving model to best_model_test_2.hdf5
# 179/179 [==============================] - 39s 220ms/step - loss: 2.6261 - accuracy: 0.1380 - val_loss: 2.6176 - val_accuracy: 0.1389
# Epoch 4/50
# 179/179 [==============================] - ETA: 0s - loss: 2.6151 - accuracy: 0.1408
# Epoch 4: saving model to best_model_test_2.hdf5
# 179/179 [==============================] - 39s 212ms/step - loss: 2.6151 - accuracy: 0.1408 - val_loss: 2.6107 - val_accuracy: 0.1389
# Epoch 5/50
# 179/179 [==============================] - ETA: 0s - loss: 2.6101 - accuracy: 0.1401
# Epoch 5: saving model to best_model_test_2.hdf5
# 179/179 [==============================] - 40s 222ms/step - loss: 2.6101 - accuracy: 0.1401 - val_loss: 2.6067 - val_accuracy: 0.1389
# Epoch 6/50
# 179/179 [==============================] - ETA: 0s - loss: 2.6080 - accuracy: 0.1394
# Epoch 6: saving model to best_model_test_2.hdf5
# 179/179 [==============================] - 41s 225ms/step - loss: 2.6080 - accuracy: 0.1394 - val_loss: 2.6044 - val_accuracy: 0.1389
# Epoch 7/50
# 179/179 [==============================] - ETA: 0s - loss: 2.6045 - accuracy: 0.1401
# Epoch 7: saving model to best_model_test_2.hdf5
# 179/179 [==============================] - 40s 223ms/step - loss: 2.6045 - accuracy: 0.1401 - val_loss: 2.6031 - val_accuracy: 0.1389
# Epoch 8/50
# 179/179 [==============================] - ETA: 0s - loss: 2.6026 - accuracy: 0.1401
# Epoch 8: saving model to best_model_test_2.hdf5
# 179/179 [==============================] - 39s 220ms/step - loss: 2.6026 - accuracy: 0.1401 - val_loss: 2.6021 - val_accuracy: 0.1389
# Epoch 9/50
# 179/179 [==============================] - ETA: 0s - loss: 2.6041 - accuracy: 0.1394
# Epoch 9: saving model to best_model_test_2.hdf5
# 179/179 [==============================] - 38s 212ms/step - loss: 2.6041 - accuracy: 0.1394 - val_loss: 2.6015 - val_accuracy: 0.1389
# Epoch 10/50
# 179/179 [==============================] - ETA: 0s - loss: 2.6034 - accuracy: 0.1401
# Epoch 10: saving model to best_model_test_2.hdf5
# 179/179 [==============================] - 40s 219ms/step - loss: 2.6034 - accuracy: 0.1401 - val_loss: 2.6012 - val_accuracy: 0.1389
# Epoch 11/50
# 179/179 [==============================] - ETA: 0s - loss: 2.6005 - accuracy: 0.1401
# Epoch 11: saving model to best_model_test_2.hdf5
# 179/179 [==============================] - 39s 216ms/step - loss: 2.6005 - accuracy: 0.1401 - val_loss: 2.6010 - val_accuracy: 0.1389
# Epoch 12/50
# 179/179 [==============================] - ETA: 0s - loss: 2.6025 - accuracy: 0.1401
# Epoch 12: saving model to best_model_test_2.hdf5
# 179/179 [==============================] - 40s 221ms/step - loss: 2.6025 - accuracy: 0.1401 - val_loss: 2.6009 - val_accuracy: 0.1389

# %% [markdown]
# ## this

# %%
model.save('./SaveModel/model_alexnet_step1.hdf5')
# model.load_weights('best_model_test_2.hdf5')

# %%
# scores = model.evaluate_generator(test_generator, verbose = 1)
scores = model.evaluate(test_generator, verbose=1)
print('Accuracy: %.2f%%' % (scores[1] * 100))
# Out:
# 45/45 [==============================] - 3s 58ms/step - loss: 2.6289 - accuracy: 0.1389
# Accuracy: 13.89%

# %%
plot_history(history)

# %% [markdown]
# ## Model Transfer Learning EfficientNetB6

# %%
input_shape
# Out:
# (250, 250, 3)

# %%
base_model = efn.EfficientNetB6(
    weights = 'imagenet',
    include_top = False,
    input_shape = input_shape
)
# Out:
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b6_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 165527152/165527152 [==============================] - 1s 0us/step

# %%
base_model.summary()
# Out:
# Model: "efficientnet-b6"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 250, 250, 3)]        0         []
#
#  stem_conv (Conv2D)          (None, 125, 125, 56)         1512      ['input_1[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 125, 125, 56)         224       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 125, 125, 56)         0         ['stem_bn[0][0]']
#  n)
#
#  block1a_dwconv (DepthwiseC  (None, 125, 125, 56)         504       ['stem_activation[0][0]']
#  onv2D)
#
#  block1a_bn (BatchNormaliza  (None, 125, 125, 56)         224       ['block1a_dwconv[0][0]']
#  tion)
#
#  block1a_activation (Activa  (None, 125, 125, 56)         0         ['block1a_bn[0][0]']
#  tion)
#
#  block1a_se_squeeze (Global  (None, 56)                   0         ['block1a_activation[0][0]']
#  AveragePooling2D)
#
#  block1a_se_reshape (Reshap  (None, 1, 1, 56)             0         ['block1a_se_squeeze[0][0]']
#  e)
#
#  block1a_se_reduce (Conv2D)  (None, 1, 1, 14)             798       ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)  (None, 1, 1, 56)             840       ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multipl  (None, 125, 125, 56)         0         ['block1a_activation[0][0]',
#  y)                                                                  'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv  (None, 125, 125, 32)         1792      ['block1a_se_excite[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 125, 125, 32)         128       ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1b_dwconv (DepthwiseC  (None, 125, 125, 32)         288       ['block1a_project_bn[0][0]']
#  onv2D)
#
#  block1b_bn (BatchNormaliza  (None, 125, 125, 32)         128       ['block1b_dwconv[0][0]']
#  tion)
#
#  block1b_activation (Activa  (None, 125, 125, 32)         0         ['block1b_bn[0][0]']
#  tion)
#
#  block1b_se_squeeze (Global  (None, 32)                   0         ['block1b_activation[0][0]']
#  AveragePooling2D)
#
#  block1b_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1b_se_squeeze[0][0]']
#  e)
#
#  block1b_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multipl  (None, 125, 125, 32)         0         ['block1b_activation[0][0]',
#  y)                                                                  'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv  (None, 125, 125, 32)         1024      ['block1b_se_excite[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 125, 125, 32)         128       ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_drop (FixedDropout  (None, 125, 125, 32)         0         ['block1b_project_bn[0][0]']
#  )
#
#  block1b_add (Add)           (None, 125, 125, 32)         0         ['block1b_drop[0][0]',
#                                                                      'block1a_project_bn[0][0]']
#
#  block1c_dwconv (DepthwiseC  (None, 125, 125, 32)         288       ['block1b_add[0][0]']
#  onv2D)
#
#  block1c_bn (BatchNormaliza  (None, 125, 125, 32)         128       ['block1c_dwconv[0][0]']
#  tion)
#
#  block1c_activation (Activa  (None, 125, 125, 32)         0         ['block1c_bn[0][0]']
#  tion)
#
#  block1c_se_squeeze (Global  (None, 32)                   0         ['block1c_activation[0][0]']
#  AveragePooling2D)
#
#  block1c_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1c_se_squeeze[0][0]']
#  e)
#
#  block1c_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1c_se_reshape[0][0]']
#
#  block1c_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1c_se_reduce[0][0]']
#
#  block1c_se_excite (Multipl  (None, 125, 125, 32)         0         ['block1c_activation[0][0]',
#  y)                                                                  'block1c_se_expand[0][0]']
#
#  block1c_project_conv (Conv  (None, 125, 125, 32)         1024      ['block1c_se_excite[0][0]']
#  2D)
#
#  block1c_project_bn (BatchN  (None, 125, 125, 32)         128       ['block1c_project_conv[0][0]']
#  ormalization)
#
#  block1c_drop (FixedDropout  (None, 125, 125, 32)         0         ['block1c_project_bn[0][0]']
#  )
#
#  block1c_add (Add)           (None, 125, 125, 32)         0         ['block1c_drop[0][0]',
#                                                                      'block1b_add[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 125, 125, 192)        6144      ['block1c_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 125, 125, 192)        768       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 125, 125, 192)        0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_dwconv (DepthwiseC  (None, 63, 63, 192)          1728      ['block2a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2a_bn (BatchNormaliza  (None, 63, 63, 192)          768       ['block2a_dwconv[0][0]']
#  tion)
#
#  block2a_activation (Activa  (None, 63, 63, 192)          0         ['block2a_bn[0][0]']
#  tion)
#
#  block2a_se_squeeze (Global  (None, 192)                  0         ['block2a_activation[0][0]']
#  AveragePooling2D)
#
#  block2a_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block2a_se_squeeze[0][0]']
#  e)
#
#  block2a_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multipl  (None, 63, 63, 192)          0         ['block2a_activation[0][0]',
#  y)                                                                  'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv  (None, 63, 63, 40)           7680      ['block2a_se_excite[0][0]']
#  2D)
#
#  block2a_project_bn (BatchN  (None, 63, 63, 40)           160       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 63, 63, 240)          9600      ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 63, 63, 240)          960       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 63, 63, 240)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_dwconv (DepthwiseC  (None, 63, 63, 240)          2160      ['block2b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2b_bn (BatchNormaliza  (None, 63, 63, 240)          960       ['block2b_dwconv[0][0]']
#  tion)
#
#  block2b_activation (Activa  (None, 63, 63, 240)          0         ['block2b_bn[0][0]']
#  tion)
#
#  block2b_se_squeeze (Global  (None, 240)                  0         ['block2b_activation[0][0]']
#  AveragePooling2D)
#
#  block2b_se_reshape (Reshap  (None, 1, 1, 240)            0         ['block2b_se_squeeze[0][0]']
#  e)
#
#  block2b_se_reduce (Conv2D)  (None, 1, 1, 10)             2410      ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)  (None, 1, 1, 240)            2640      ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multipl  (None, 63, 63, 240)          0         ['block2b_activation[0][0]',
#  y)                                                                  'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv  (None, 63, 63, 40)           9600      ['block2b_se_excite[0][0]']
#  2D)
#
#  block2b_project_bn (BatchN  (None, 63, 63, 40)           160       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (FixedDropout  (None, 63, 63, 40)           0         ['block2b_project_bn[0][0]']
#  )
#
#  block2b_add (Add)           (None, 63, 63, 40)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 63, 63, 240)          9600      ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 63, 63, 240)          960       ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 63, 63, 240)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_dwconv (DepthwiseC  (None, 63, 63, 240)          2160      ['block2c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2c_bn (BatchNormaliza  (None, 63, 63, 240)          960       ['block2c_dwconv[0][0]']
#  tion)
#
#  block2c_activation (Activa  (None, 63, 63, 240)          0         ['block2c_bn[0][0]']
#  tion)
#
#  block2c_se_squeeze (Global  (None, 240)                  0         ['block2c_activation[0][0]']
#  AveragePooling2D)
#
#  block2c_se_reshape (Reshap  (None, 1, 1, 240)            0         ['block2c_se_squeeze[0][0]']
#  e)
#
#  block2c_se_reduce (Conv2D)  (None, 1, 1, 10)             2410      ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)  (None, 1, 1, 240)            2640      ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multipl  (None, 63, 63, 240)          0         ['block2c_activation[0][0]',
#  y)                                                                  'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv  (None, 63, 63, 40)           9600      ['block2c_se_excite[0][0]']
#  2D)
#
#  block2c_project_bn (BatchN  (None, 63, 63, 40)           160       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (FixedDropout  (None, 63, 63, 40)           0         ['block2c_project_bn[0][0]']
#  )
#
#  block2c_add (Add)           (None, 63, 63, 40)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2  (None, 63, 63, 240)          9600      ['block2c_add[0][0]']
#  D)
#
#  block2d_expand_bn (BatchNo  (None, 63, 63, 240)          960       ['block2d_expand_conv[0][0]']
#  rmalization)
#
#  block2d_expand_activation   (None, 63, 63, 240)          0         ['block2d_expand_bn[0][0]']
#  (Activation)
#
#  block2d_dwconv (DepthwiseC  (None, 63, 63, 240)          2160      ['block2d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2d_bn (BatchNormaliza  (None, 63, 63, 240)          960       ['block2d_dwconv[0][0]']
#  tion)
#
#  block2d_activation (Activa  (None, 63, 63, 240)          0         ['block2d_bn[0][0]']
#  tion)
#
#  block2d_se_squeeze (Global  (None, 240)                  0         ['block2d_activation[0][0]']
#  AveragePooling2D)
#
#  block2d_se_reshape (Reshap  (None, 1, 1, 240)            0         ['block2d_se_squeeze[0][0]']
#  e)
#
#  block2d_se_reduce (Conv2D)  (None, 1, 1, 10)             2410      ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)  (None, 1, 1, 240)            2640      ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multipl  (None, 63, 63, 240)          0         ['block2d_activation[0][0]',
#  y)                                                                  'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv  (None, 63, 63, 40)           9600      ['block2d_se_excite[0][0]']
#  2D)
#
#  block2d_project_bn (BatchN  (None, 63, 63, 40)           160       ['block2d_project_conv[0][0]']
#  ormalization)
#
#  block2d_drop (FixedDropout  (None, 63, 63, 40)           0         ['block2d_project_bn[0][0]']
#  )
#
#  block2d_add (Add)           (None, 63, 63, 40)           0         ['block2d_drop[0][0]',
#                                                                      'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2  (None, 63, 63, 240)          9600      ['block2d_add[0][0]']
#  D)
#
#  block2e_expand_bn (BatchNo  (None, 63, 63, 240)          960       ['block2e_expand_conv[0][0]']
#  rmalization)
#
#  block2e_expand_activation   (None, 63, 63, 240)          0         ['block2e_expand_bn[0][0]']
#  (Activation)
#
#  block2e_dwconv (DepthwiseC  (None, 63, 63, 240)          2160      ['block2e_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2e_bn (BatchNormaliza  (None, 63, 63, 240)          960       ['block2e_dwconv[0][0]']
#  tion)
#
#  block2e_activation (Activa  (None, 63, 63, 240)          0         ['block2e_bn[0][0]']
#  tion)
#
#  block2e_se_squeeze (Global  (None, 240)                  0         ['block2e_activation[0][0]']
#  AveragePooling2D)
#
#  block2e_se_reshape (Reshap  (None, 1, 1, 240)            0         ['block2e_se_squeeze[0][0]']
#  e)
#
#  block2e_se_reduce (Conv2D)  (None, 1, 1, 10)             2410      ['block2e_se_reshape[0][0]']
#
#  block2e_se_expand (Conv2D)  (None, 1, 1, 240)            2640      ['block2e_se_reduce[0][0]']
#
#  block2e_se_excite (Multipl  (None, 63, 63, 240)          0         ['block2e_activation[0][0]',
#  y)                                                                  'block2e_se_expand[0][0]']
#
#  block2e_project_conv (Conv  (None, 63, 63, 40)           9600      ['block2e_se_excite[0][0]']
#  2D)
#
#  block2e_project_bn (BatchN  (None, 63, 63, 40)           160       ['block2e_project_conv[0][0]']
#  ormalization)
#
#  block2e_drop (FixedDropout  (None, 63, 63, 40)           0         ['block2e_project_bn[0][0]']
#  )
#
#  block2e_add (Add)           (None, 63, 63, 40)           0         ['block2e_drop[0][0]',
#                                                                      'block2d_add[0][0]']
#
#  block2f_expand_conv (Conv2  (None, 63, 63, 240)          9600      ['block2e_add[0][0]']
#  D)
#
#  block2f_expand_bn (BatchNo  (None, 63, 63, 240)          960       ['block2f_expand_conv[0][0]']
#  rmalization)
#
#  block2f_expand_activation   (None, 63, 63, 240)          0         ['block2f_expand_bn[0][0]']
#  (Activation)
#
#  block2f_dwconv (DepthwiseC  (None, 63, 63, 240)          2160      ['block2f_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2f_bn (BatchNormaliza  (None, 63, 63, 240)          960       ['block2f_dwconv[0][0]']
#  tion)
#
#  block2f_activation (Activa  (None, 63, 63, 240)          0         ['block2f_bn[0][0]']
#  tion)
#
#  block2f_se_squeeze (Global  (None, 240)                  0         ['block2f_activation[0][0]']
#  AveragePooling2D)
#
#  block2f_se_reshape (Reshap  (None, 1, 1, 240)            0         ['block2f_se_squeeze[0][0]']
#  e)
#
#  block2f_se_reduce (Conv2D)  (None, 1, 1, 10)             2410      ['block2f_se_reshape[0][0]']
#
#  block2f_se_expand (Conv2D)  (None, 1, 1, 240)            2640      ['block2f_se_reduce[0][0]']
#
#  block2f_se_excite (Multipl  (None, 63, 63, 240)          0         ['block2f_activation[0][0]',
#  y)                                                                  'block2f_se_expand[0][0]']
#
#  block2f_project_conv (Conv  (None, 63, 63, 40)           9600      ['block2f_se_excite[0][0]']
#  2D)
#
#  block2f_project_bn (BatchN  (None, 63, 63, 40)           160       ['block2f_project_conv[0][0]']
#  ormalization)
#
#  block2f_drop (FixedDropout  (None, 63, 63, 40)           0         ['block2f_project_bn[0][0]']
#  )
#
#  block2f_add (Add)           (None, 63, 63, 40)           0         ['block2f_drop[0][0]',
#                                                                      'block2e_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 63, 63, 240)          9600      ['block2f_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 63, 63, 240)          960       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 63, 63, 240)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_dwconv (DepthwiseC  (None, 32, 32, 240)          6000      ['block3a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3a_bn (BatchNormaliza  (None, 32, 32, 240)          960       ['block3a_dwconv[0][0]']
#  tion)
#
#  block3a_activation (Activa  (None, 32, 32, 240)          0         ['block3a_bn[0][0]']
#  tion)
#
#  block3a_se_squeeze (Global  (None, 240)                  0         ['block3a_activation[0][0]']
#  AveragePooling2D)
#
#  block3a_se_reshape (Reshap  (None, 1, 1, 240)            0         ['block3a_se_squeeze[0][0]']
#  e)
#
#  block3a_se_reduce (Conv2D)  (None, 1, 1, 10)             2410      ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)  (None, 1, 1, 240)            2640      ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multipl  (None, 32, 32, 240)          0         ['block3a_activation[0][0]',
#  y)                                                                  'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv  (None, 32, 32, 72)           17280     ['block3a_se_excite[0][0]']
#  2D)
#
#  block3a_project_bn (BatchN  (None, 32, 32, 72)           288       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 32, 32, 432)          31104     ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 32, 32, 432)          1728      ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 32, 32, 432)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_dwconv (DepthwiseC  (None, 32, 32, 432)          10800     ['block3b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3b_bn (BatchNormaliza  (None, 32, 32, 432)          1728      ['block3b_dwconv[0][0]']
#  tion)
#
#  block3b_activation (Activa  (None, 32, 32, 432)          0         ['block3b_bn[0][0]']
#  tion)
#
#  block3b_se_squeeze (Global  (None, 432)                  0         ['block3b_activation[0][0]']
#  AveragePooling2D)
#
#  block3b_se_reshape (Reshap  (None, 1, 1, 432)            0         ['block3b_se_squeeze[0][0]']
#  e)
#
#  block3b_se_reduce (Conv2D)  (None, 1, 1, 18)             7794      ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)  (None, 1, 1, 432)            8208      ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multipl  (None, 32, 32, 432)          0         ['block3b_activation[0][0]',
#  y)                                                                  'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv  (None, 32, 32, 72)           31104     ['block3b_se_excite[0][0]']
#  2D)
#
#  block3b_project_bn (BatchN  (None, 32, 32, 72)           288       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (FixedDropout  (None, 32, 32, 72)           0         ['block3b_project_bn[0][0]']
#  )
#
#  block3b_add (Add)           (None, 32, 32, 72)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2  (None, 32, 32, 432)          31104     ['block3b_add[0][0]']
#  D)
#
#  block3c_expand_bn (BatchNo  (None, 32, 32, 432)          1728      ['block3c_expand_conv[0][0]']
#  rmalization)
#
#  block3c_expand_activation   (None, 32, 32, 432)          0         ['block3c_expand_bn[0][0]']
#  (Activation)
#
#  block3c_dwconv (DepthwiseC  (None, 32, 32, 432)          10800     ['block3c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3c_bn (BatchNormaliza  (None, 32, 32, 432)          1728      ['block3c_dwconv[0][0]']
#  tion)
#
#  block3c_activation (Activa  (None, 32, 32, 432)          0         ['block3c_bn[0][0]']
#  tion)
#
#  block3c_se_squeeze (Global  (None, 432)                  0         ['block3c_activation[0][0]']
#  AveragePooling2D)
#
#  block3c_se_reshape (Reshap  (None, 1, 1, 432)            0         ['block3c_se_squeeze[0][0]']
#  e)
#
#  block3c_se_reduce (Conv2D)  (None, 1, 1, 18)             7794      ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)  (None, 1, 1, 432)            8208      ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multipl  (None, 32, 32, 432)          0         ['block3c_activation[0][0]',
#  y)                                                                  'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv  (None, 32, 32, 72)           31104     ['block3c_se_excite[0][0]']
#  2D)
#
#  block3c_project_bn (BatchN  (None, 32, 32, 72)           288       ['block3c_project_conv[0][0]']
#  ormalization)
#
#  block3c_drop (FixedDropout  (None, 32, 32, 72)           0         ['block3c_project_bn[0][0]']
#  )
#
#  block3c_add (Add)           (None, 32, 32, 72)           0         ['block3c_drop[0][0]',
#                                                                      'block3b_add[0][0]']
#
# ...
#  tion)
#
#  block6k_se_squeeze (Global  (None, 2064)                 0         ['block6k_activation[0][0]']
#  AveragePooling2D)
#
#  block6k_se_reshape (Reshap  (None, 1, 1, 2064)           0         ['block6k_se_squeeze[0][0]']
#  e)
#
#  block6k_se_reduce (Conv2D)  (None, 1, 1, 86)             177590    ['block6k_se_reshape[0][0]']
#
#  block6k_se_expand (Conv2D)  (None, 1, 1, 2064)           179568    ['block6k_se_reduce[0][0]']
#
#  block6k_se_excite (Multipl  (None, 8, 8, 2064)           0         ['block6k_activation[0][0]',
#  y)                                                                  'block6k_se_expand[0][0]']
#
#  block6k_project_conv (Conv  (None, 8, 8, 344)            710016    ['block6k_se_excite[0][0]']
#  2D)
#
#  block6k_project_bn (BatchN  (None, 8, 8, 344)            1376      ['block6k_project_conv[0][0]']
#  ormalization)
#
#  block6k_drop (FixedDropout  (None, 8, 8, 344)            0         ['block6k_project_bn[0][0]']
#  )
#
#  block6k_add (Add)           (None, 8, 8, 344)            0         ['block6k_drop[0][0]',
#                                                                      'block6j_add[0][0]']
#
#  block7a_expand_conv (Conv2  (None, 8, 8, 2064)           710016    ['block6k_add[0][0]']
#  D)
#
#  block7a_expand_bn (BatchNo  (None, 8, 8, 2064)           8256      ['block7a_expand_conv[0][0]']
#  rmalization)
#
#  block7a_expand_activation   (None, 8, 8, 2064)           0         ['block7a_expand_bn[0][0]']
#  (Activation)
#
#  block7a_dwconv (DepthwiseC  (None, 8, 8, 2064)           18576     ['block7a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7a_bn (BatchNormaliza  (None, 8, 8, 2064)           8256      ['block7a_dwconv[0][0]']
#  tion)
#
#  block7a_activation (Activa  (None, 8, 8, 2064)           0         ['block7a_bn[0][0]']
#  tion)
#
#  block7a_se_squeeze (Global  (None, 2064)                 0         ['block7a_activation[0][0]']
#  AveragePooling2D)
#
#  block7a_se_reshape (Reshap  (None, 1, 1, 2064)           0         ['block7a_se_squeeze[0][0]']
#  e)
#
#  block7a_se_reduce (Conv2D)  (None, 1, 1, 86)             177590    ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)  (None, 1, 1, 2064)           179568    ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multipl  (None, 8, 8, 2064)           0         ['block7a_activation[0][0]',
#  y)                                                                  'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv  (None, 8, 8, 576)            1188864   ['block7a_se_excite[0][0]']
#  2D)
#
#  block7a_project_bn (BatchN  (None, 8, 8, 576)            2304      ['block7a_project_conv[0][0]']
#  ormalization)
#
#  block7b_expand_conv (Conv2  (None, 8, 8, 3456)           1990656   ['block7a_project_bn[0][0]']
#  D)
#
#  block7b_expand_bn (BatchNo  (None, 8, 8, 3456)           13824     ['block7b_expand_conv[0][0]']
#  rmalization)
#
#  block7b_expand_activation   (None, 8, 8, 3456)           0         ['block7b_expand_bn[0][0]']
#  (Activation)
#
#  block7b_dwconv (DepthwiseC  (None, 8, 8, 3456)           31104     ['block7b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7b_bn (BatchNormaliza  (None, 8, 8, 3456)           13824     ['block7b_dwconv[0][0]']
#  tion)
#
#  block7b_activation (Activa  (None, 8, 8, 3456)           0         ['block7b_bn[0][0]']
#  tion)
#
#  block7b_se_squeeze (Global  (None, 3456)                 0         ['block7b_activation[0][0]']
#  AveragePooling2D)
#
#  block7b_se_reshape (Reshap  (None, 1, 1, 3456)           0         ['block7b_se_squeeze[0][0]']
#  e)
#
#  block7b_se_reduce (Conv2D)  (None, 1, 1, 144)            497808    ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)  (None, 1, 1, 3456)           501120    ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multipl  (None, 8, 8, 3456)           0         ['block7b_activation[0][0]',
#  y)                                                                  'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv  (None, 8, 8, 576)            1990656   ['block7b_se_excite[0][0]']
#  2D)
#
#  block7b_project_bn (BatchN  (None, 8, 8, 576)            2304      ['block7b_project_conv[0][0]']
#  ormalization)
#
#  block7b_drop (FixedDropout  (None, 8, 8, 576)            0         ['block7b_project_bn[0][0]']
#  )
#
#  block7b_add (Add)           (None, 8, 8, 576)            0         ['block7b_drop[0][0]',
#                                                                      'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2  (None, 8, 8, 3456)           1990656   ['block7b_add[0][0]']
#  D)
#
#  block7c_expand_bn (BatchNo  (None, 8, 8, 3456)           13824     ['block7c_expand_conv[0][0]']
#  rmalization)
#
#  block7c_expand_activation   (None, 8, 8, 3456)           0         ['block7c_expand_bn[0][0]']
#  (Activation)
#
#  block7c_dwconv (DepthwiseC  (None, 8, 8, 3456)           31104     ['block7c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7c_bn (BatchNormaliza  (None, 8, 8, 3456)           13824     ['block7c_dwconv[0][0]']
#  tion)
#
#  block7c_activation (Activa  (None, 8, 8, 3456)           0         ['block7c_bn[0][0]']
#  tion)
#
#  block7c_se_squeeze (Global  (None, 3456)                 0         ['block7c_activation[0][0]']
#  AveragePooling2D)
#
#  block7c_se_reshape (Reshap  (None, 1, 1, 3456)           0         ['block7c_se_squeeze[0][0]']
#  e)
#
#  block7c_se_reduce (Conv2D)  (None, 1, 1, 144)            497808    ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)  (None, 1, 1, 3456)           501120    ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multipl  (None, 8, 8, 3456)           0         ['block7c_activation[0][0]',
#  y)                                                                  'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv  (None, 8, 8, 576)            1990656   ['block7c_se_excite[0][0]']
#  2D)
#
#  block7c_project_bn (BatchN  (None, 8, 8, 576)            2304      ['block7c_project_conv[0][0]']
#  ormalization)
#
#  block7c_drop (FixedDropout  (None, 8, 8, 576)            0         ['block7c_project_bn[0][0]']
#  )
#
#  block7c_add (Add)           (None, 8, 8, 576)            0         ['block7c_drop[0][0]',
#                                                                      'block7b_add[0][0]']
#
#  top_conv (Conv2D)           (None, 8, 8, 2304)           1327104   ['block7c_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 8, 8, 2304)           9216      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 8, 8, 2304)           0         ['top_bn[0][0]']
#  )
#
# ==================================================================================================
# Total params: 40960136 (156.25 MB)
# Trainable params: 40735704 (155.39 MB)
# Non-trainable params: 224432 (876.69 KB)
# __________________________________________________________________________________________________

# %%
base_model.trainable = False

# %%
model = M.Sequential()
model.add(base_model)
model.add(L.GlobalAveragePooling2D())
model.add(L.Dense(CLASS_NUM, activation = 'softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnet-b6 (Functiona  (None, 8, 8, 2304)        40960136
#  l)
#
#  global_average_pooling2d (  (None, 2304)              0
#  GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 15)                34575
#
# =================================================================
# Total params: 40994711 (156.38 MB)
# Trainable params: 34575 (135.06 KB)
# Non-trainable params: 40960136 (156.25 MB)
# _________________________________________________________________

# %%
print(len(model.layers))
# Out:
# 3

# %%
len(model.trainable_variables)
# Out:
# 2

# %%
# check the trainable status of the individual layers
for layer in model.layers:
    print(layer, layer.trainable)
# Out:
# <keras.src.engine.functional.Functional object at 0x7b75fb28b940> False
# <keras.src.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D object at 0x7b75f845cb50> True
# <keras.src.layers.core.dense.Dense object at 0x7b75fb28ec50> True

# %% [markdown]
# ### Step 1: Freeze Base Layer + Training new Head Classifier

# %%
model.compile(
    loss = 'categorical_crossentropy',
    optimizer = optimizers.Adam(learning_rate = LR_step1),
    metrics = ['accuracy']
)

# %%
checkpoint = ModelCheckpoint(
    'best_model.hdf5',
    monitor = ['val_accuracy'],
    verbose = 1,
    mode = 'max'
)
earlystop = EarlyStopping(
    monitor = 'val_accuracy',
    patience = 5,
    restore_best_weights = True
)
callbacks_list = [checkpoint, earlystop]

# %% [markdown]
# Đánh giá trước khi huấn luyện

# %%
# scores = model.evaluate_generator(test_generator, verbose = 1)
scores = model.evaluate(test_generator, verbose=1)
print('Accuracy: %.2f%%' % (scores[1] * 100))
# Out:
# 45/45 [==============================] - 15s 90ms/step - loss: 2.7351 - accuracy: 0.0444
# Accuracy: 4.44%

# %%
print(train_generator.samples)
# Out:
# 1436

# %%
# fit include generator
history = model.fit(
    train_generator,
    steps_per_epoch = train_generator.samples // train_generator.batch_size,
    validation_data = test_generator,
    validation_steps = test_generator.samples // test_generator.batch_size,
    epochs = 5,
    callbacks = callbacks_list
)
# Out:
# Epoch 1/5
# 179/179 [==============================] - ETA: 0s - loss: 1.7102 - accuracy: 0.5154
# Epoch 1: saving model to best_model.hdf5
# 179/179 [==============================] - 69s 295ms/step - loss: 1.7102 - accuracy: 0.5154 - val_loss: 0.9887 - val_accuracy: 0.7250
# Epoch 2/5
# 179/179 [==============================] - ETA: 0s - loss: 1.0187 - accuracy: 0.7143
# Epoch 2: saving model to best_model.hdf5
# 179/179 [==============================] - 44s 246ms/step - loss: 1.0187 - accuracy: 0.7143 - val_loss: 0.6962 - val_accuracy: 0.8167
# Epoch 3/5
# 179/179 [==============================] - ETA: 0s - loss: 0.8090 - accuracy: 0.7794
# Epoch 3: saving model to best_model.hdf5
# 179/179 [==============================] - 44s 246ms/step - loss: 0.8090 - accuracy: 0.7794 - val_loss: 0.5525 - val_accuracy: 0.8667
# Epoch 4/5
# 179/179 [==============================] - ETA: 0s - loss: 0.6722 - accuracy: 0.8123
# Epoch 4: saving model to best_model.hdf5
# 179/179 [==============================] - 44s 242ms/step - loss: 0.6722 - accuracy: 0.8123 - val_loss: 0.4682 - val_accuracy: 0.8889
# Epoch 5/5
# 179/179 [==============================] - ETA: 0s - loss: 0.6286 - accuracy: 0.8277
# Epoch 5: saving model to best_model.hdf5
# 179/179 [==============================] - 44s 246ms/step - loss: 0.6286 - accuracy: 0.8277 - val_loss: 0.4287 - val_accuracy: 0.8889

# %%
model.save('./SaveModel/model_step1.hdf5')
model.load_weights('best_model.hdf5')

# %% [markdown]
# Đánh giá sau khi huấn luyện

# %%
# scores = model.evaluate_generator(test_generator, verbose = 1)
scores = model.evaluate(test_generator, verbose=1)
print('Accuracy: %.2f%%' % (scores[1] * 100))
# Out:
# 45/45 [==============================] - 4s 95ms/step - loss: 0.4287 - accuracy: 0.8889
# Accuracy: 88.89%

# %% [markdown]
# Visualizer training history

# %%
def plot_history(history):
    plt.figure(figsize = (10, 5))
#     plt.style.use('dark_background')
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(len(acc))
    plt.plot(epochs, acc, 'b', label = 'Training acc')
    plt.plot(epochs, val_acc, 'g', label = 'Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()
#     plt.figure()
    plt.figure(figsize = (10, 5))
#     plt.style.use('dark_background')
    plt.plot(epochs, loss, 'b', label = 'Training loss')
    plt.plot(epochs, val_loss, 'g', label = 'Validation loss')
    plt.title('Training and validation loss')
    plt.legend()
    plt.show()


plot_history(history)

# %% [markdown]
# ### Step 2: Freeze a half layers of base_model and fine-turning

# %%
# let's take a look to see how many layers are in the base model
print('Number of layers in the base model:', len(base_model.layers))
# Out:
# Number of layers in the base model: 659

# %%
base_model.trainable = True

# fine-tune from this layer onwards
fine_tune_at = len(base_model.layers) // 2

# freeze all the layers before the 'fine_tune_at' layer
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False

# %%
len(base_model.trainable_variables)
# Out:
# 291

# %%
# check the trainable status of the individual layers
for layer in model.layers:
    print(layer, layer.trainable)
# Out:
# <keras.src.engine.functional.Functional object at 0x7b75fb28b940> True
# <keras.src.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D object at 0x7b75f845cb50> True
# <keras.src.layers.core.dense.Dense object at 0x7b75fb28ec50> True

# %%
model.compile(
    loss = 'categorical_crossentropy',
    optimizer = optimizers.Adam(learning_rate = LR_step2),
    metrics = ['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnet-b6 (Functiona  (None, 8, 8, 2304)        40960136
#  l)
#
#  global_average_pooling2d (  (None, 2304)              0
#  GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 15)                34575
#
# =================================================================
# Total params: 40994711 (156.38 MB)
# Trainable params: 37731045 (143.93 MB)
# Non-trainable params: 3263666 (12.45 MB)
# _________________________________________________________________

# %%
scores = model.evaluate(test_generator, verbose=1)
print('Accuracy: %.2f%%' % (scores[1] * 100))
# Out:
# 45/45 [==============================] - 10s 94ms/step - loss: 0.4287 - accuracy: 0.8889
# Accuracy: 88.89%

# %%
history = model.fit(
    train_generator,
    steps_per_epoch = train_generator.samples // train_generator.batch_size,
    validation_data = test_generator,
    validation_steps = test_generator.samples // test_generator.batch_size,
    epochs = 10,
    callbacks = callbacks_list
)

# %%
model.save('./SaveModel/model_step2.hdf5')
model.load_weights('best_model.hdf5')

# %%
scores = model.evaluate(test_generator, verbose = 1)
print('Accuracy: %.2f%%' % (scores[1] * 100))

# %%
plot_history(history)

# %% [markdown]
# ### Step 3: No Freeze Base model and full fine-turning

# %%
base_model.trainable = True

# %%
model.compile(
    loss = 'categorical_crossentropy',
    optimizer = optimizers.Adam(lr = LR_step3),
    metrics = ['accuracy']
)

# %%
history = model.fit(
    train_generator,
    steps_per_epoch = train_generator.samples // train_generator.batch_size,
    validation_data = test_generator,
    validation_steps = test_generator.samples // test_generator.batch_size,
    epochs = 10,
    callbacks = callbacks_list
)

# %%
model.save('./SaveModel/model_step3.hdf5')
model.load_weights('best_model.hdf5')

# %%
scores = model.evaluate_generator(test_generator, verbose = 1)
print('Accuracy: %.2f%%' % (scores[1] * 100))

# %% [markdown]
# ## Final Score

# %%
from sklearn.metrics import accuracy_score

# %%
model.load_weights('best_model.hdf5')

# %%
predictions = model.predict(test_generator, verbose = 1)
predictions = np.argmax(predictions, axis = -1)         # multiple categories
label_map = (train_generator.class_indices)
label_map = dict((v, k) for k, v in label_map.items())  # flip k, v
predictions = [label_map[k] for k in predictions]

# %%
filenames_with_dir = test_generator.filenames
submission = pd.DataFrame(
    {'Predict': predictions},
    columns = ['Predict'],
    index = filenames_with_dir
)
test_files.index = test_files['Id']
tmp_y = pd.concat(
    [submission['Predict'], test_files['Category']],
    axis = 1,
    sort = False
)
tmp_y.head(5)

# %%
print('Accuracy: %.2f%%' % (
    accuracy_score(tmp_y['Category'], tmp_y['Predict']) * 100
))

# %% [markdown]
# ### confusion matrix

# %%
from sklearn.metrics import confusion_matrix

# tmp_y['Category'] là nhãn thực tế, tmp_y['Predict'] là dự đoán của mô hình
conf_matrix = confusion_matrix(tmp_y['Category'], tmp_y['Predict'])

print("Confusion Matrix:")
print(conf_matrix)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Vẽ heatmap cho confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
# In ra các trường hợp nhầm lẫn
for i in range(len(conf_matrix)):
    for j in range(len(conf_matrix)):
        if i != j and conf_matrix[i][j] > 0:
            print("Thực tế:", i, "Dự đoán:", j, "Số lượng:", conf_matrix[i][j])

# %%
# Tính tổng số lượng nhầm lẫn cho từng loại
errors_per_category = conf_matrix.sum(axis=1)

# Xây dựng bảng thống kê
error_table = []
for i, error_count in enumerate(errors_per_category):
    error_table.append({'Loại': i, 'Số lượng nhầm lẫn': error_count})

# Sắp xếp bảng thống kê theo số lượng nhầm lẫn giảm dần
error_table.sort(key=lambda x: x['Số lượng nhầm lẫn'], reverse=True)

# In bảng thống kê
print("Bảng thống kê số loại bị nhầm lẫn nhiều nhất từ cao đến thấp:")
for item in error_table:
    print("Loại:", item['Loại'], "- Số lượng nhầm lẫn:", item['Số lượng nhầm lẫn'])

# %%
# Lấy thông tin để vẽ biểu đồ
categories = [str(item['Loại']) for item in error_table[0:15]]
errors = [item['Số lượng nhầm lẫn'] for item in error_table[0:15]]

# Vẽ biểu đồ
plt.figure(figsize=(10, 6))
plt.bar(categories, errors, color='skyblue')
plt.xlabel('Loại')
plt.ylabel('Số lượng nhầm lẫn')
plt.title('Số lượng loại bị nhầm lẫn nhiều nhất từ cao đến thấp cho từng loại')
plt.xticks(categories)
plt.show()

# %% [markdown]
# Category: ['48', '76', '42', '72', '89', '73', '81', '95', '88', '77', '37', '39', '83', '96', '74']

# %%
print(categories)

# %% [markdown]
# Đây là các 15 loại nhầm lẫn nhiều nhất.
# Công việc tiếp theo:
# - Tính ra % chính xác của model efficientnetB6 với 15 loại này (dự đoán sẽ giảm so với 84% trên toàn bộ tập dữ liệu)
# - Cắt bộ dữ liệu ra 15 loại
# - Huấn luyện trên model Lenet5 với 37tr tham số, Alexnet, GoogleNet và thống kê kết quả

# %% [markdown]
# tính độ chính xác của 15 loại trên best model efficientNetB6:
# - phải huấn luyện lại mô hình trên 15 loại này
# - rồi đánh giá lại, mà huấn luyện rất mất thời gian, chắc là dùng lại model hiện giờ luôn.
